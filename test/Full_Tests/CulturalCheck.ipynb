# %%
import os
import subprocess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import sys
sys.path.append('../pca_full')  # Adjust the path as needed
from pca_full import pca_full

# Ensure reproducibility
np.random.seed(42)

# Define the OHspecial_transform function
def OHspecial_transform(df):
    names = df.columns.values
    data = df.values
    labels = []
    
    for j in range(len(names)):
        col_data = data[:, j]
        temp = np.unique(col_data[~np.isnan(col_data)])
        temp = temp[temp >= 0]
        
        if len(temp) == 0:
            # All data in column j is NaN or negative
            var = col_data.reshape(-1, 1)
            label = [names[j]]
        elif len(temp) <= 2:
            # Keep original data
            var = col_data.reshape(-1, 1)
            label = [names[j]]
        else:
            # One-hot encode
            var = np.zeros((data.shape[0], len(temp)))
            for l in range(len(temp)):
                var[:, l] = np.where(col_data == temp[l], 1, 0)
            idx = np.where(np.isnan(col_data))[0]
            var[idx, :] = np.nan
            # Use str instead of int to match MATLAB's num2str behavior
            label = [f"{names[j]}_{str(temp[l])}" for l in range(len(temp))]
        
        if j == 0:
            OH = var
        else:
            OH = np.hstack((OH, var))
        labels.extend(label)
    
    OH_df = pd.DataFrame(OH, columns=labels)
    OH_df.to_parquet("OHspecial_transformed_iso_data.parquet")
    return OH_df

# Read in data and remove non-cultural features + features missing > 50% of possible values

# From EA
KinOrgRaw = pd.read_csv('KinshipOrgDataRaw.csv')
SubRaw = pd.read_csv('SubsistenceDataRaw.csv')
# EA_All_Raw = pd.read_csv('EA_All.csv')  # Commented out in MATLAB code

# From Pulotu
IsoRaw = pd.read_csv('IsoDataRaw.csv')
ReligRaw = pd.read_csv('RelDataRaw.csv')

# Other datasets
Binford = pd.read_csv('Binford_all.csv')
Seshat = pd.read_csv('Seshat.csv')
Birds = pd.read_csv('data_birds_OH.csv')

# Apply OHspecial_transform to datasets
KinOrg = OHspecial_transform(KinOrgRaw)
Sub = OHspecial_transform(SubRaw)
Iso = OHspecial_transform(IsoRaw)
Relig = OHspecial_transform(ReligRaw)

for w in range(4, 5):

    if w == 1:
        X = KinOrg
    elif w == 2:
        X = Sub
    elif w == 3:
        X = Relig
    elif w == 4:
        X = Iso
    elif w == 5:
        X = Binford
    elif w == 6:
        X = Seshat
    elif w == 7:
        X = Birds

    # Remove features missing > 50% of their entries
    dim = X.shape
    X = X.iloc[:, 0:dim[1]]  # Redundant but kept for similarity
    cols = X.columns.values
    X = X.to_numpy()

    counts = []
    for j in range(dim[1]):
        temp = np.isnan(X[:, j]).astype(int)
        idx = np.where(temp == 1)[0]
        counts.append(len(idx))

    counts = np.array(counts) / dim[0]
    idx = np.where(counts > 0.5)[0]
    cols = np.delete(cols, idx)
    X = np.delete(X, idx, axis=1)
    dim = X.shape

    # Compute initial mean and standard deviation, ignoring NaNs
    MnInit = np.tile(np.nanmean(X, axis=0), (dim[0], 1))
    STDInit = np.tile(np.nanstd(X, axis=0), (dim[0], 1))

    if w < 5:
        X_ = X - MnInit
    elif w == 5:
        X_ = X
    elif w == 6:
        X_ = (X - MnInit) / STDInit
    elif w == 7:
        X_ = X

    X_ = X_.T

    MaxStop = min(dim)
    if MaxStop > 100:
        MaxStop = 100
    zz = np.arange(2, MaxStop + 1)

    # Initialize lists for dynamic data collection
    rms = []
    accu = []
    rmsA = []
    costA = []
    var_exp = []
    # X_start = pd.DataFrame(X_).to_numpy(copy=True)
    # X_start = np.copy(X_)
    # pd.DataFrame(X_).to_csv("python_X_before_for.csv", index=False)
    print(f"NaN count in X_ before for (", np.isnan(X_).sum())
    # print(f"NaN count in X_start before for (", np.isnan(X_start).sum())

    for y in range(MaxStop - 1):
        print (f"iteration {y} out of {MaxStop - 1}")

        z = zz[y]
        print('###############################')
        print(f'Number of PCs: {z}')
        print('###############################')
        if y > 0:
            time.sleep(1)

        for k in range(1):  # Change if you want to do replications

            opts = {
                'maxiters': 80,
                'algorithm': 'vb',
                'uniquesv': 0,
                'rmsstop': [80, np.finfo(float).eps, np.finfo(float).eps],
                'cfstop': [80, 0, 0],
                'minangle': 0
            }

            result = pca_full(np.copy(X_), z, **opts)
            A = result['A']
            S = result['S']
            Mu = result['Mu']
            V = result['V']
            cv = result['cv']
            hp = result['hp']
            lc = result['lc']

            if z == 20:
                plt.figure()
                plt.scatter(S[0, :], S[1, :])
                plt.title('Scatter plot of first two PCs')
                plt.show()

            print('Learning is finished.')

            Xrec = Mu + A @ S
            
            accu_num = np.abs(np.round(Xrec.T + MnInit) - X_.T)
            accu_num = len(np.where(accu_num > 0)[0])
        
            # diff = np.round(Xrec.T + MnInit) - X_.T
            print("xrec: ", Xrec.T)
            print("MnInit: ", MnInit)
            print(f"Number of non-matching elements (accu_num): {accu_num}")
        
            total_elements = len(np.where(~np.isnan(X_.flatten()))[0])
            print(f"Total number of elements in X_: {total_elements}")
        
            accu_value = 1 - accu_num / total_elements
            print(f"Calculated accuracy: {accu_value}")
            # accu_value = 1 - accu_num / len(np.where(~np.isnan(X_.flatten()))[0])
            accu.append(accu_value)

            # Record rms and append lc['rms'] and lc['cost']
            rms_value = lc['rms'][-1]
            rms.append(rms_value)
            rmsA.append(lc['rms'])
            costA.append(lc['cost'])

            # Compute explained variance
            vv = np.zeros(MaxStop)
            v = np.linalg.eigvals(np.cov(Xrec))
            v = np.flipud(np.sort(np.real(v)))
            v = v[:MaxStop]
            v = np.round(v, 4)
            v = v / np.sum(v)
            vv[:len(v)] = v
            var_exp.append(vv)

        print(f"Improvement: {rms[y] - rms[y - 1]}")
        if y > 0 and (rms[y] - rms[y - 1]) > 0:
            print("Breaking loop early due to positive improvement.")
            break

    # After the loop, convert lists to NumPy arrays
    rmsA.append(lc['rms'][-1])
    costA.append(lc['cost'][-1])

    var_exp = np.array(var_exp)
    rms = np.array(rms)
    accu = np.array(accu)

    # Since w == 7
    result = pca_full(X_, zz[y - 1], **opts)
    AFin = np.array(result['A'])
    SFin = np.array(result['S'])
    MuFin = np.array(result['Mu']).flatten()
    VFin = result['V']
    cvFin = result['cv']
    hpFin = result['hp']
    lcFin = result['lc']
    Xrec = MuFin[:, np.newaxis] + AFin @ SFin

    # Compute Vr
    Vr = np.zeros_like(X_)
    for i in range(X_.shape[0]):
        for j in range(X_.shape[1]):
            Vr[i, j] = (AFin[i, :] @ cvFin['S'][j] @ AFin[i, :].T +
                        SFin[:, j].T @ cvFin['A'][i] @ SFin[:, j] +
                        np.sum(cvFin['S'][j] * cvFin['A'][i]) +
                        cvFin['Mu'][i])
    VrFin = Vr

    # Save reconstructed data
    T = pd.DataFrame(Xrec.T, columns=cols)
    T.to_csv('Finch_VBPCA_Recon_All.csv', index=False)
    XrecFin = Xrec
    rmsFin = rms
    rmsAFin = rmsA
    costAFin = costA
    var_exp_Fin = var_exp
    accu_Fin = accu

    # Plot scatter of the first two PCs
    plt.figure()
    plt.scatter(SFin[0, :], SFin[1, :], c='b', marker='o')
    plt.title('Isolation')
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.show()

    # Plot Accuracy and RMS vs Number of PCs
    plt.figure()
    fig, ax1 = plt.subplots()
    
    # Plot Accuracy on the left y-axis
    color = 'tab:blue'
    ax1.set_xlabel('Number of PCs')
    ax1.set_ylabel('Accuracy', color=color)
    x_values = np.arange(2, len(accu_Fin) + 2)
    ax1.plot(x_values, accu_Fin, color=color, linewidth=2, marker='o')
    ax1.tick_params(axis='y', labelcolor=color)
    
    # Plot RMS on the right y-axis
    ax2 = ax1.twinx()
    color = 'tab:red'
    ax2.set_ylabel('RMS', color=color)
    ax2.plot(x_values, rmsFin, color=color, linewidth=2, marker='o')
    ax2.tick_params(axis='y', labelcolor=color)
    
    # Add a vertical line at the final number of PCs
    ax1.axvline(x=len(accu_Fin) + 1, linewidth=2, color='black')
    
    # Set x-axis limits
    ax1.set_xlim([2, len(accu_Fin) + 1])
    
    # Add grid, title, and adjust font size
    ax1.grid(True)
    plt.title(r'Conflict \& Contact')
    plt.rcParams.update({'font.size': 18})
    
    # Show the plot
    plt.show()

    # Clear variables (optional in Python, but included for completeness)
    del rmsA
    del costA
    del var_exp
    del Vr
    del accu
# Out:
# NaN count in X_ before for ( 124
# iteration 0 out of 17
# ###############################
# Number of PCs: 2
# ###############################
# No empty rows or columns
# Step 0: rms = 0.501331
# Step 1: cost = 1541.530317, rms = 0.394619
# Step 2: cost = 1451.004154, rms = 0.393590
# Step 3: cost = 1431.738313, rms = 0.384644
# Step 4: cost = 1333.707091, rms = 0.346410
# Step 5: cost = 1248.448540, rms = 0.319281
# Step 6: cost = 1230.227952, rms = 0.312730
# Step 7: cost = 1227.653663, rms = 0.311357
# Step 8: cost = 1227.070616, rms = 0.311012
# Step 9: cost = 1226.860088, rms = 0.310907
# Step 10: cost = 1226.762934, rms = 0.310867
# Step 11: cost = 1226.711415, rms = 0.310848
# Step 12: cost = 1226.681969, rms = 0.310838
# Step 13: cost = 1226.664514, rms = 0.310833
# Step 14: cost = 1226.654002, rms = 0.310830
# Step 15: cost = 1226.647640, rms = 0.310827
# Step 16: cost = 1226.643793, rms = 0.310826
# Step 17: cost = 1226.641479, rms = 0.310825
# Step 18: cost = 1226.640102, rms = 0.310825
# Step 19: cost = 1226.639294, rms = 0.310825
# Step 20: cost = 1226.638832, rms = 0.310824
# Step 21: cost = 1226.638577, rms = 0.310824
# Step 22: cost = 1226.638446, rms = 0.310824
# Step 23: cost = 1226.638385, rms = 0.310824
# Step 24: cost = 1226.638365, rms = 0.310824
# Step 25: cost = 1226.638367, rms = 0.310824
# Step 26: cost = 1226.638379, rms = 0.310824
# Step 27: cost = 1226.638396, rms = 0.310824
# Step 28: cost = 1226.638414, rms = 0.310824
# Step 29: cost = 1226.638431, rms = 0.310824
# Step 30: cost = 1226.638447, rms = 0.310824
# Step 31: cost = 1226.638460, rms = 0.310824
# Step 32: cost = 1226.638471, rms = 0.310824
# Step 33: cost = 1226.638481, rms = 0.310824
# Step 34: cost = 1226.638489, rms = 0.310824
# Step 35: cost = 1226.638495, rms = 0.310824
# Step 36: cost = 1226.638500, rms = 0.310824
# Step 37: cost = 1226.638504, rms = 0.310824
# Step 38: cost = 1226.638508, rms = 0.310824
# Step 39: cost = 1226.638511, rms = 0.310824
# Step 40: cost = 1226.638513, rms = 0.310824
# Step 41: cost = 1226.638515, rms = 0.310824
# Step 42: cost = 1226.638516, rms = 0.310824
# Step 43: cost = 1226.638517, rms = 0.310824
# Step 44: cost = 1226.638518, rms = 0.310824
# Step 45: cost = 1226.638519, rms = 0.310824
# Step 46: cost = 1226.638520, rms = 0.310824
# Step 47: cost = 1226.638520, rms = 0.310824
# Step 48: cost = 1226.638520, rms = 0.310824
# Step 49: cost = 1226.638520, rms = 0.310824
# Step 50: cost = 1226.638521, rms = 0.310824
# Step 51: cost = 1226.638521, rms = 0.310824
# Step 52: cost = 1226.638521, rms = 0.310824
# Step 53: cost = 1226.638521, rms = 0.310824
# Step 54: cost = 1226.638521, rms = 0.310824
# Step 55: cost = 1226.638521, rms = 0.310824
# Step 56: cost = 1226.638522, rms = 0.310824
# Step 57: cost = 1226.638521, rms = 0.310824
# Step 58: cost = 1226.638522, rms = 0.310824
# Step 59: cost = 1226.638521, rms = 0.310824
# Step 60: cost = 1226.638522, rms = 0.310824
# Step 61: cost = 1226.638522, rms = 0.310824
# Step 62: cost = 1226.638522, rms = 0.310824
# Step 63: cost = 1226.638522, rms = 0.310824
# Step 64: cost = 1226.638522, rms = 0.310824
# Step 65: cost = 1226.638522, rms = 0.310824
# Step 66: cost = 1226.638522, rms = 0.310824
# Step 67: cost = 1226.638522, rms = 0.310824
# Step 68: cost = 1226.638522, rms = 0.310824
# Step 69: cost = 1226.638522, rms = 0.310824
# Step 70: cost = 1226.638522, rms = 0.310824
# Step 71: cost = 1226.638522, rms = 0.310824
# Step 72: cost = 1226.638522, rms = 0.310824
# Step 73: cost = 1226.638522, rms = 0.310824
# Step 74: cost = 1226.638522, rms = 0.310824
# Step 75: cost = 1226.638522, rms = 0.310824
# Step 76: cost = 1226.638522, rms = 0.310824
# Step 77: cost = 1226.638522, rms = 0.310824
# Step 78: cost = 1226.638522, rms = 0.310824
# Step 79: cost = 1226.638522, rms = 0.310824
# Step 80: cost = 1226.638522, rms = 0.310824
# Learning is finished.
# xrec:  [[-0.4463884  -0.00265074  0.44903914 ...  0.15263308  0.03064856
#   -0.36353322]
#  [ 0.50907037 -0.00101763 -0.50805274 ... -0.14522294 -0.05750739
#    0.37352716]
#  [-0.3646622   0.00979433  0.35486788 ...  0.04093312  0.09329235
#   -0.18045323]
#  ...
#  [ 0.14000045  0.01774072 -0.15774117 ... -0.16602664  0.08713221
#    0.27795396]
#  [-0.10052281  0.01661923  0.08390358 ... -0.08606802  0.10527253
#    0.08547989]
#  [ 0.49510182 -0.00922165 -0.48588017 ... -0.08355097 -0.10287438
#    0.2829571 ]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: 0.0
# iteration 1 out of 17
# ###############################
# Number of PCs: 3
# ###############################
# No empty rows or columns
# Step 0: rms = 0.577914
# Step 1: cost = 1626.142589, rms = 0.394184
# Step 2: cost = 1506.505799, rms = 0.391280
# Step 3: cost = 1448.635936, rms = 0.367559
# Step 4: cost = 1354.628297, rms = 0.334768
# Step 5: cost = 1278.458161, rms = 0.305114
# Step 6: cost = 1230.566871, rms = 0.287212
# Step 7: cost = 1219.322254, rms = 0.282033
# Step 8: cost = 1217.570465, rms = 0.280719
# Step 9: cost = 1217.110519, rms = 0.280333
# Step 10: cost = 1216.880901, rms = 0.280198
# Step 11: cost = 1216.724660, rms = 0.280138
# Step 12: cost = 1216.604285, rms = 0.280104
# Step 13: cost = 1216.506330, rms = 0.280080
# Step 14: cost = 1216.424478, rms = 0.280062
# Step 15: cost = 1216.355129, rms = 0.280048
# Step 16: cost = 1216.295918, rms = 0.280037
# Step 17: cost = 1216.245137, rms = 0.280027
# Step 18: cost = 1216.201467, rms = 0.280019
# Step 19: cost = 1216.163855, rms = 0.280013
# Step 20: cost = 1216.131428, rms = 0.280008
# Step 21: cost = 1216.103453, rms = 0.280003
# Step 22: cost = 1216.079308, rms = 0.279999
# Step 23: cost = 1216.058466, rms = 0.279996
# Step 24: cost = 1216.040470, rms = 0.279994
# Step 25: cost = 1216.024931, rms = 0.279992
# Step 26: cost = 1216.011511, rms = 0.279990
# Step 27: cost = 1215.999921, rms = 0.279989
# Step 28: cost = 1215.989911, rms = 0.279988
# Step 29: cost = 1215.981267, rms = 0.279987
# Step 30: cost = 1215.973800, rms = 0.279986
# Step 31: cost = 1215.967351, rms = 0.279986
# Step 32: cost = 1215.961781, rms = 0.279985
# Step 33: cost = 1215.956972, rms = 0.279985
# Step 34: cost = 1215.952817, rms = 0.279985
# Step 35: cost = 1215.949230, rms = 0.279985
# Step 36: cost = 1215.946134, rms = 0.279985
# Step 37: cost = 1215.943461, rms = 0.279985
# Step 38: cost = 1215.941153, rms = 0.279985
# Step 39: cost = 1215.939161, rms = 0.279985
# Step 40: cost = 1215.937443, rms = 0.279985
# Step 41: cost = 1215.935962, rms = 0.279985
# Step 42: cost = 1215.934683, rms = 0.279985
# Step 43: cost = 1215.933581, rms = 0.279985
# Step 44: cost = 1215.932631, rms = 0.279986
# Step 45: cost = 1215.931814, rms = 0.279986
# Step 46: cost = 1215.931109, rms = 0.279986
# Step 47: cost = 1215.930503, rms = 0.279986
# Step 48: cost = 1215.929981, rms = 0.279986
# Step 49: cost = 1215.929534, rms = 0.279986
# Step 50: cost = 1215.929148, rms = 0.279986
# Step 51: cost = 1215.928817, rms = 0.279987
# Step 52: cost = 1215.928533, rms = 0.279987
# Step 53: cost = 1215.928291, rms = 0.279987
# Step 54: cost = 1215.928082, rms = 0.279987
# Step 55: cost = 1215.927904, rms = 0.279987
# Step 56: cost = 1215.927752, rms = 0.279987
# Step 57: cost = 1215.927623, rms = 0.279987
# Step 58: cost = 1215.927512, rms = 0.279988
# Step 59: cost = 1215.927418, rms = 0.279988
# Step 60: cost = 1215.927338, rms = 0.279988
# Step 61: cost = 1215.927272, rms = 0.279988
# Step 62: cost = 1215.927214, rms = 0.279988
# Step 63: cost = 1215.927165, rms = 0.279988
# Step 64: cost = 1215.927125, rms = 0.279988
# Step 65: cost = 1215.927092, rms = 0.279988
# Step 66: cost = 1215.927063, rms = 0.279988
# Step 67: cost = 1215.927040, rms = 0.279988
# Step 68: cost = 1215.927020, rms = 0.279988
# Step 69: cost = 1215.927006, rms = 0.279988
# Step 70: cost = 1215.926992, rms = 0.279988
# Step 71: cost = 1215.926981, rms = 0.279989
# Step 72: cost = 1215.926973, rms = 0.279989
# Step 73: cost = 1215.926968, rms = 0.279989
# Step 74: cost = 1215.926962, rms = 0.279989
# Step 75: cost = 1215.926958, rms = 0.279989
# Step 76: cost = 1215.926955, rms = 0.279989
# Step 77: cost = 1215.926955, rms = 0.279989
# Step 78: cost = 1215.926953, rms = 0.279989
# Step 79: cost = 1215.926952, rms = 0.279989
# Step 80: cost = 1215.926952, rms = 0.279989
# Learning is finished.
# xrec:  [[-3.85704876e-01 -3.97894101e-03  3.89683817e-01 ...  8.43229446e-02
#    1.68486973e-01 -4.59684565e-01]
#  [ 4.26898016e-01  4.89981163e-04 -4.27387997e-01 ... -5.30031528e-02
#   -2.39338720e-01  4.95953723e-01]
#  [-3.15291291e-01  9.19577138e-03  3.06095520e-01 ... -2.26805015e-02
#    2.11432414e-01 -2.53780690e-01]
#  ...
#  [ 8.47309849e-02  1.95956386e-02 -1.04326624e-01 ... -1.21343061e-01
#   -1.60561204e-02  3.60986105e-01]
#  [-2.05080614e-01  1.91412728e-02  1.85939341e-01 ...  2.44079960e-03
#   -7.77222026e-02  2.13133809e-01]
#  [ 4.97365046e-01 -9.42599899e-03 -4.87939047e-01 ... -6.91257066e-02
#   -1.29956999e-01  3.02963192e-01]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.030835014626591384
# iteration 2 out of 17
# ###############################
# Number of PCs: 4
# ###############################
# No empty rows or columns
# Step 0: rms = 0.622665
# Step 1: cost = 1724.047423, rms = 0.396699
# Step 2: cost = 1565.512789, rms = 0.390264
# Step 3: cost = 1504.269911, rms = 0.365375
# Step 4: cost = 1417.443708, rms = 0.334545
# Step 5: cost = 1336.660405, rms = 0.301645
# Step 6: cost = 1253.072276, rms = 0.269820
# Step 7: cost = 1206.795239, rms = 0.253472
# Step 8: cost = 1195.407019, rms = 0.248626
# Step 9: cost = 1193.064094, rms = 0.247145
# Step 10: cost = 1192.423140, rms = 0.246641
# Step 11: cost = 1192.188633, rms = 0.246458
# Step 12: cost = 1192.088714, rms = 0.246389
# Step 13: cost = 1192.043225, rms = 0.246361
# Step 14: cost = 1192.021835, rms = 0.246349
# Step 15: cost = 1192.011587, rms = 0.246344
# Step 16: cost = 1192.006618, rms = 0.246342
# Step 17: cost = 1192.004193, rms = 0.246341
# Step 18: cost = 1192.003004, rms = 0.246341
# Step 19: cost = 1192.002422, rms = 0.246340
# Step 20: cost = 1192.002137, rms = 0.246340
# Step 21: cost = 1192.002000, rms = 0.246340
# Step 22: cost = 1192.001934, rms = 0.246340
# Step 23: cost = 1192.001904, rms = 0.246340
# Step 24: cost = 1192.001891, rms = 0.246340
# Step 25: cost = 1192.001885, rms = 0.246340
# Step 26: cost = 1192.001884, rms = 0.246340
# Step 27: cost = 1192.001884, rms = 0.246340
# Step 28: cost = 1192.001884, rms = 0.246340
# Step 29: cost = 1192.001885, rms = 0.246340
# Step 30: cost = 1192.001885, rms = 0.246340
# Step 31: cost = 1192.001886, rms = 0.246340
# Step 32: cost = 1192.001886, rms = 0.246340
# Step 33: cost = 1192.001887, rms = 0.246340
# Step 34: cost = 1192.001887, rms = 0.246340
# Step 35: cost = 1192.001887, rms = 0.246340
# Step 36: cost = 1192.001887, rms = 0.246340
# Step 37: cost = 1192.001887, rms = 0.246340
# Step 38: cost = 1192.001887, rms = 0.246340
# Step 39: cost = 1192.001887, rms = 0.246340
# Step 40: cost = 1192.001887, rms = 0.246340
# Step 41: cost = 1192.001887, rms = 0.246340
# Step 42: cost = 1192.001887, rms = 0.246340
# Step 43: cost = 1192.001887, rms = 0.246340
# Step 44: cost = 1192.001887, rms = 0.246340
# Step 45: cost = 1192.001887, rms = 0.246340
# Step 46: cost = 1192.001887, rms = 0.246340
# Step 47: cost = 1192.001887, rms = 0.246340
# Step 48: cost = 1192.001887, rms = 0.246340
# Step 49: cost = 1192.001887, rms = 0.246340
# Step 50: cost = 1192.001887, rms = 0.246340
# Step 51: cost = 1192.001887, rms = 0.246340
# Step 52: cost = 1192.001887, rms = 0.246340
# Step 53: cost = 1192.001887, rms = 0.246340
# Step 54: cost = 1192.001887, rms = 0.246340
# Step 55: cost = 1192.001887, rms = 0.246340
# Step 56: cost = 1192.001887, rms = 0.246340
# Step 57: cost = 1192.001887, rms = 0.246340
# Step 58: cost = 1192.001887, rms = 0.246340
# Step 59: cost = 1192.001887, rms = 0.246340
# Step 60: cost = 1192.001887, rms = 0.246340
# Step 61: cost = 1192.001887, rms = 0.246340
# Step 62: cost = 1192.001887, rms = 0.246340
# Step 63: cost = 1192.001887, rms = 0.246340
# Step 64: cost = 1192.001887, rms = 0.246340
# Step 65: cost = 1192.001887, rms = 0.246340
# Step 66: cost = 1192.001887, rms = 0.246340
# Step 67: cost = 1192.001887, rms = 0.246340
# Step 68: cost = 1192.001887, rms = 0.246340
# Step 69: cost = 1192.001887, rms = 0.246340
# Step 70: cost = 1192.001887, rms = 0.246340
# Step 71: cost = 1192.001887, rms = 0.246340
# Step 72: cost = 1192.001887, rms = 0.246340
# Step 73: cost = 1192.001887, rms = 0.246340
# Step 74: cost = 1192.001887, rms = 0.246340
# Step 75: cost = 1192.001887, rms = 0.246340
# Step 76: cost = 1192.001887, rms = 0.246340
# Step 77: cost = 1192.001887, rms = 0.246340
# Step 78: cost = 1192.001887, rms = 0.246340
# Step 79: cost = 1192.001887, rms = 0.246340
# Step 80: cost = 1192.001887, rms = 0.246340
# Learning is finished.
# xrec:  [[-0.41994857 -0.00672635  0.42667492 ... -0.0708969   0.02042215
#   -0.31654218]
#  [ 0.45164297  0.00223182 -0.45387479 ...  0.05365618 -0.15249479
#    0.41064447]
#  [-0.29967035  0.01169968  0.28797067 ...  0.09697408  0.35507735
#   -0.39564729]
#  ...
#  [ 0.06769465  0.01875955 -0.0864542  ... -0.23321423 -0.12688944
#    0.48732581]
#  [-0.23422112  0.01818288  0.21603824 ... -0.11379665 -0.20416634
#    0.34719679]
#  [ 0.49702624 -0.01138316 -0.48564309 ... -0.15526698 -0.22794656
#    0.40398557]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.033648538049926624
# iteration 3 out of 17
# ###############################
# Number of PCs: 5
# ###############################
# No empty rows or columns
# Step 0: rms = 0.659188
# Step 1: cost = 1802.110083, rms = 0.396083
# Step 2: cost = 1626.997638, rms = 0.390639
# Step 3: cost = 1565.861577, rms = 0.365203
# Step 4: cost = 1465.999198, rms = 0.328753
# Step 5: cost = 1391.176539, rms = 0.298746
# Step 6: cost = 1323.391000, rms = 0.271580
# Step 7: cost = 1270.240314, rms = 0.252037
# Step 8: cost = 1242.322749, rms = 0.240396
# Step 9: cost = 1214.989550, rms = 0.229202
# Step 10: cost = 1203.492809, rms = 0.223984
# Step 11: cost = 1200.854250, rms = 0.222221
# Step 12: cost = 1200.095015, rms = 0.221563
# Step 13: cost = 1199.787593, rms = 0.221298
# Step 14: cost = 1199.629578, rms = 0.221185
# Step 15: cost = 1199.537026, rms = 0.221134
# Step 16: cost = 1199.478978, rms = 0.221110
# Step 17: cost = 1199.441156, rms = 0.221098
# Step 18: cost = 1199.415947, rms = 0.221091
# Step 19: cost = 1199.398899, rms = 0.221087
# Step 20: cost = 1199.387259, rms = 0.221084
# Step 21: cost = 1199.379258, rms = 0.221083
# Step 22: cost = 1199.373728, rms = 0.221082
# Step 23: cost = 1199.369886, rms = 0.221081
# Step 24: cost = 1199.367205, rms = 0.221080
# Step 25: cost = 1199.365326, rms = 0.221080
# Step 26: cost = 1199.364002, rms = 0.221080
# Step 27: cost = 1199.363064, rms = 0.221080
# Step 28: cost = 1199.362397, rms = 0.221079
# Step 29: cost = 1199.361917, rms = 0.221079
# Step 30: cost = 1199.361571, rms = 0.221079
# Step 31: cost = 1199.361320, rms = 0.221079
# Step 32: cost = 1199.361135, rms = 0.221079
# Step 33: cost = 1199.360998, rms = 0.221079
# Step 34: cost = 1199.360896, rms = 0.221079
# Step 35: cost = 1199.360820, rms = 0.221079
# Step 36: cost = 1199.360761, rms = 0.221079
# Step 37: cost = 1199.360716, rms = 0.221079
# Step 38: cost = 1199.360682, rms = 0.221079
# Step 39: cost = 1199.360655, rms = 0.221079
# Step 40: cost = 1199.360633, rms = 0.221079
# Step 41: cost = 1199.360617, rms = 0.221079
# Step 42: cost = 1199.360603, rms = 0.221079
# Step 43: cost = 1199.360592, rms = 0.221079
# Step 44: cost = 1199.360584, rms = 0.221079
# Step 45: cost = 1199.360577, rms = 0.221079
# Step 46: cost = 1199.360571, rms = 0.221079
# Step 47: cost = 1199.360567, rms = 0.221079
# Step 48: cost = 1199.360563, rms = 0.221079
# Step 49: cost = 1199.360560, rms = 0.221079
# Step 50: cost = 1199.360557, rms = 0.221079
# Step 51: cost = 1199.360555, rms = 0.221079
# Step 52: cost = 1199.360553, rms = 0.221079
# Step 53: cost = 1199.360552, rms = 0.221079
# Step 54: cost = 1199.360550, rms = 0.221079
# Step 55: cost = 1199.360550, rms = 0.221079
# Step 56: cost = 1199.360549, rms = 0.221079
# Step 57: cost = 1199.360548, rms = 0.221079
# Step 58: cost = 1199.360548, rms = 0.221079
# Step 59: cost = 1199.360547, rms = 0.221079
# Step 60: cost = 1199.360547, rms = 0.221079
# Step 61: cost = 1199.360546, rms = 0.221079
# Step 62: cost = 1199.360546, rms = 0.221079
# Step 63: cost = 1199.360546, rms = 0.221079
# Step 64: cost = 1199.360546, rms = 0.221079
# Step 65: cost = 1199.360546, rms = 0.221079
# Step 66: cost = 1199.360545, rms = 0.221079
# Step 67: cost = 1199.360545, rms = 0.221079
# Step 68: cost = 1199.360545, rms = 0.221079
# Step 69: cost = 1199.360545, rms = 0.221079
# Step 70: cost = 1199.360545, rms = 0.221079
# Step 71: cost = 1199.360545, rms = 0.221079
# Step 72: cost = 1199.360545, rms = 0.221079
# Step 73: cost = 1199.360545, rms = 0.221079
# Step 74: cost = 1199.360545, rms = 0.221079
# Step 75: cost = 1199.360545, rms = 0.221079
# Step 76: cost = 1199.360545, rms = 0.221079
# Step 77: cost = 1199.360545, rms = 0.221079
# Step 78: cost = 1199.360545, rms = 0.221079
# Step 79: cost = 1199.360545, rms = 0.221079
# Step 80: cost = 1199.360545, rms = 0.221079
# Learning is finished.
# xrec:  [[-0.40273418 -0.00589576  0.40862994 ... -0.07433467 -0.16976591
#   -0.24344525]
#  [ 0.47167266  0.00293233 -0.474605   ...  0.06077824 -0.29426536
#    0.48492618]
#  [-0.29963335  0.01222269  0.28741066 ...  0.08933374  0.37927165
#   -0.41386472]
#  ...
#  [ 0.07326412  0.01967212 -0.09293624 ... -0.24374783 -0.17149739
#    0.51618936]
#  [-0.23878867  0.01905915  0.21972952 ... -0.12160829 -0.22798385
#    0.36479108]
#  [ 0.50392624 -0.01173702 -0.49218922 ... -0.15388024 -0.24970904
#    0.42410701]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.025261211846170833
# iteration 4 out of 17
# ###############################
# Number of PCs: 6
# ###############################
# No empty rows or columns
# Step 0: rms = 0.700695
# Step 1: cost = 1876.251987, rms = 0.393898
# Step 2: cost = 1680.596626, rms = 0.387059
# Step 3: cost = 1603.587495, rms = 0.356740
# Step 4: cost = 1522.893287, rms = 0.325886
# Step 5: cost = 1433.249073, rms = 0.289005
# Step 6: cost = 1359.493624, rms = 0.261262
# Step 7: cost = 1330.457197, rms = 0.250143
# Step 8: cost = 1319.558456, rms = 0.244543
# Step 9: cost = 1301.056657, rms = 0.235636
# Step 10: cost = 1266.678349, rms = 0.220853
# Step 11: cost = 1234.953646, rms = 0.207961
# Step 12: cost = 1223.038330, rms = 0.202295
# Step 13: cost = 1219.729442, rms = 0.200047
# Step 14: cost = 1218.689949, rms = 0.199060
# Step 15: cost = 1218.302447, rms = 0.198597
# Step 16: cost = 1218.130756, rms = 0.198368
# Step 17: cost = 1218.043364, rms = 0.198248
# Step 18: cost = 1217.994129, rms = 0.198181
# Step 19: cost = 1217.964178, rms = 0.198141
# Step 20: cost = 1217.944804, rms = 0.198115
# Step 21: cost = 1217.931632, rms = 0.198097
# Step 22: cost = 1217.922314, rms = 0.198084
# Step 23: cost = 1217.915514, rms = 0.198074
# Step 24: cost = 1217.910431, rms = 0.198066
# Step 25: cost = 1217.906562, rms = 0.198060
# Step 26: cost = 1217.903574, rms = 0.198056
# Step 27: cost = 1217.901240, rms = 0.198052
# Step 28: cost = 1217.899402, rms = 0.198049
# Step 29: cost = 1217.897941, rms = 0.198047
# Step 30: cost = 1217.896774, rms = 0.198045
# Step 31: cost = 1217.895837, rms = 0.198043
# Step 32: cost = 1217.895083, rms = 0.198042
# Step 33: cost = 1217.894470, rms = 0.198041
# Step 34: cost = 1217.893972, rms = 0.198040
# Step 35: cost = 1217.893567, rms = 0.198039
# Step 36: cost = 1217.893236, rms = 0.198039
# Step 37: cost = 1217.892963, rms = 0.198038
# Step 38: cost = 1217.892740, rms = 0.198038
# Step 39: cost = 1217.892556, rms = 0.198038
# Step 40: cost = 1217.892405, rms = 0.198037
# Step 41: cost = 1217.892279, rms = 0.198037
# Step 42: cost = 1217.892175, rms = 0.198037
# Step 43: cost = 1217.892088, rms = 0.198037
# Step 44: cost = 1217.892018, rms = 0.198037
# Step 45: cost = 1217.891957, rms = 0.198037
# Step 46: cost = 1217.891907, rms = 0.198037
# Step 47: cost = 1217.891866, rms = 0.198036
# Step 48: cost = 1217.891832, rms = 0.198036
# Step 49: cost = 1217.891802, rms = 0.198036
# Step 50: cost = 1217.891778, rms = 0.198036
# Step 51: cost = 1217.891757, rms = 0.198036
# Step 52: cost = 1217.891742, rms = 0.198036
# Step 53: cost = 1217.891726, rms = 0.198036
# Step 54: cost = 1217.891714, rms = 0.198036
# Step 55: cost = 1217.891704, rms = 0.198036
# Step 56: cost = 1217.891697, rms = 0.198036
# Step 57: cost = 1217.891688, rms = 0.198036
# Step 58: cost = 1217.891682, rms = 0.198036
# Step 59: cost = 1217.891677, rms = 0.198036
# Step 60: cost = 1217.891674, rms = 0.198036
# Step 61: cost = 1217.891669, rms = 0.198036
# Step 62: cost = 1217.891666, rms = 0.198036
# Step 63: cost = 1217.891663, rms = 0.198036
# Step 64: cost = 1217.891663, rms = 0.198036
# Step 65: cost = 1217.891660, rms = 0.198036
# Step 66: cost = 1217.891658, rms = 0.198036
# Step 67: cost = 1217.891656, rms = 0.198036
# Step 68: cost = 1217.891657, rms = 0.198036
# Step 69: cost = 1217.891655, rms = 0.198036
# Step 70: cost = 1217.891654, rms = 0.198036
# Step 71: cost = 1217.891653, rms = 0.198036
# Step 72: cost = 1217.891654, rms = 0.198036
# Step 73: cost = 1217.891652, rms = 0.198036
# Step 74: cost = 1217.891651, rms = 0.198036
# Step 75: cost = 1217.891651, rms = 0.198036
# Step 76: cost = 1217.891652, rms = 0.198036
# Step 77: cost = 1217.891651, rms = 0.198036
# Step 78: cost = 1217.891650, rms = 0.198036
# Step 79: cost = 1217.891650, rms = 0.198036
# Step 80: cost = 1217.891651, rms = 0.198036
# Learning is finished.
# xrec:  [[-0.42811622 -0.00995291  0.43806914 ... -0.14261908 -0.17085602
#   -0.24704089]
#  [ 0.4968062   0.0061289  -0.5029351  ...  0.11960374 -0.31598043
#    0.49889593]
#  [-0.30595547  0.01199848  0.29395699 ...  0.07944193  0.3953801
#   -0.42549323]
#  ...
#  [ 0.09731194  0.02424464 -0.12155658 ... -0.17895909 -0.18543175
#    0.53458766]
#  [-0.2474195   0.01923288  0.22818662 ... -0.13151729 -0.23484604
#    0.37825233]
#  [ 0.55862248 -0.00396755 -0.55465494 ... -0.01997382 -0.27709715
#    0.44164621]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.023043023925217537
# iteration 5 out of 17
# ###############################
# Number of PCs: 7
# ###############################
# No empty rows or columns
# Step 0: rms = 0.752409
# Step 1: cost = 1961.768041, rms = 0.395379
# Step 2: cost = 1741.819603, rms = 0.387053
# Step 3: cost = 1662.773648, rms = 0.355636
# Step 4: cost = 1575.317217, rms = 0.321745
# Step 5: cost = 1489.757398, rms = 0.286179
# Step 6: cost = 1417.436269, rms = 0.257661
# Step 7: cost = 1374.753320, rms = 0.240428
# Step 8: cost = 1347.495547, rms = 0.228799
# Step 9: cost = 1335.378117, rms = 0.222795
# Step 10: cost = 1324.364498, rms = 0.217068
# Step 11: cost = 1307.853985, rms = 0.209327
# Step 12: cost = 1296.869822, rms = 0.203828
# Step 13: cost = 1290.647120, rms = 0.200381
# Step 14: cost = 1279.186679, rms = 0.195137
# Step 15: cost = 1258.914646, rms = 0.186709
# Step 16: cost = 1246.083076, rms = 0.180922
# Step 17: cost = 1240.904735, rms = 0.178050
# Step 18: cost = 1237.833573, rms = 0.176285
# Step 19: cost = 1235.559938, rms = 0.175009
# Step 20: cost = 1233.905830, rms = 0.174054
# Step 21: cost = 1232.811886, rms = 0.173368
# Step 22: cost = 1232.141165, rms = 0.172900
# Step 23: cost = 1231.739831, rms = 0.172593
# Step 24: cost = 1231.494978, rms = 0.172395
# Step 25: cost = 1231.338996, rms = 0.172266
# Step 26: cost = 1231.234532, rms = 0.172182
# Step 27: cost = 1231.161184, rms = 0.172126
# Step 28: cost = 1231.107578, rms = 0.172088
# Step 29: cost = 1231.067108, rms = 0.172061
# Step 30: cost = 1231.035782, rms = 0.172041
# Step 31: cost = 1231.011073, rms = 0.172027
# Step 32: cost = 1230.991306, rms = 0.172015
# Step 33: cost = 1230.975330, rms = 0.172006
# Step 34: cost = 1230.962324, rms = 0.171999
# Step 35: cost = 1230.951676, rms = 0.171994
# Step 36: cost = 1230.942925, rms = 0.171989
# Step 37: cost = 1230.935713, rms = 0.171985
# Step 38: cost = 1230.929752, rms = 0.171981
# Step 39: cost = 1230.924824, rms = 0.171978
# Step 40: cost = 1230.920735, rms = 0.171976
# Step 41: cost = 1230.917344, rms = 0.171974
# Step 42: cost = 1230.914526, rms = 0.171972
# Step 43: cost = 1230.912185, rms = 0.171970
# Step 44: cost = 1230.910235, rms = 0.171969
# Step 45: cost = 1230.908611, rms = 0.171968
# Step 46: cost = 1230.907257, rms = 0.171967
# Step 47: cost = 1230.906124, rms = 0.171966
# Step 48: cost = 1230.905180, rms = 0.171965
# Step 49: cost = 1230.904391, rms = 0.171964
# Step 50: cost = 1230.903726, rms = 0.171964
# Step 51: cost = 1230.903169, rms = 0.171963
# Step 52: cost = 1230.902701, rms = 0.171962
# Step 53: cost = 1230.902307, rms = 0.171962
# Step 54: cost = 1230.901976, rms = 0.171962
# Step 55: cost = 1230.901699, rms = 0.171961
# Step 56: cost = 1230.901460, rms = 0.171961
# Step 57: cost = 1230.901260, rms = 0.171961
# Step 58: cost = 1230.901089, rms = 0.171960
# Step 59: cost = 1230.900945, rms = 0.171960
# Step 60: cost = 1230.900824, rms = 0.171960
# Step 61: cost = 1230.900718, rms = 0.171960
# Step 62: cost = 1230.900625, rms = 0.171960
# Step 63: cost = 1230.900548, rms = 0.171959
# Step 64: cost = 1230.900480, rms = 0.171959
# Step 65: cost = 1230.900423, rms = 0.171959
# Step 66: cost = 1230.900375, rms = 0.171959
# Step 67: cost = 1230.900332, rms = 0.171959
# Step 68: cost = 1230.900293, rms = 0.171959
# Step 69: cost = 1230.900261, rms = 0.171959
# Step 70: cost = 1230.900233, rms = 0.171959
# Step 71: cost = 1230.900209, rms = 0.171959
# Step 72: cost = 1230.900189, rms = 0.171959
# Step 73: cost = 1230.900170, rms = 0.171959
# Step 74: cost = 1230.900151, rms = 0.171959
# Step 75: cost = 1230.900136, rms = 0.171959
# Step 76: cost = 1230.900122, rms = 0.171958
# Step 77: cost = 1230.900111, rms = 0.171958
# Step 78: cost = 1230.900103, rms = 0.171958
# Step 79: cost = 1230.900093, rms = 0.171958
# Step 80: cost = 1230.900084, rms = 0.171958
# Learning is finished.
# xrec:  [[-0.41195923 -0.01474354  0.42670277 ... -0.15666389 -0.18725882
#   -0.26907881]
#  [ 0.52256432  0.00417358 -0.5267379  ...  0.13562108 -0.33374963
#    0.49741722]
#  [-0.2848652   0.00551153  0.27935367 ...  0.08258779  0.42002462
#   -0.47611793]
#  ...
#  [ 0.07858193  0.03114932 -0.10973126 ... -0.18920985 -0.19921916
#    0.58246301]
#  [-0.28177236  0.02606601  0.25570635 ... -0.14526432 -0.24580325
#    0.42616084]
#  [ 0.57332417 -0.00221269 -0.57111148 ... -0.01054278 -0.29295636
#    0.45784219]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.026077726864446482
# iteration 6 out of 17
# ###############################
# Number of PCs: 8
# ###############################
# No empty rows or columns
# Step 0: rms = 0.759918
# Step 1: cost = 2043.396044, rms = 0.395972
# Step 2: cost = 1797.947221, rms = 0.384501
# Step 3: cost = 1710.509398, rms = 0.350519
# Step 4: cost = 1627.705277, rms = 0.317233
# Step 5: cost = 1542.328542, rms = 0.281047
# Step 6: cost = 1475.060394, rms = 0.254746
# Step 7: cost = 1438.837718, rms = 0.239469
# Step 8: cost = 1412.348527, rms = 0.227806
# Step 9: cost = 1396.562232, rms = 0.219962
# Step 10: cost = 1376.348968, rms = 0.210271
# Step 11: cost = 1355.679933, rms = 0.200421
# Step 12: cost = 1336.242880, rms = 0.190932
# Step 13: cost = 1317.365475, rms = 0.182043
# Step 14: cost = 1296.859307, rms = 0.172780
# Step 15: cost = 1269.873346, rms = 0.162109
# Step 16: cost = 1253.832414, rms = 0.155626
# Step 17: cost = 1245.352054, rms = 0.151863
# Step 18: cost = 1239.631955, rms = 0.149232
# Step 19: cost = 1235.931760, rms = 0.147402
# Step 20: cost = 1233.800454, rms = 0.146213
# Step 21: cost = 1232.620490, rms = 0.145472
# Step 22: cost = 1231.944217, rms = 0.145013
# Step 23: cost = 1231.532422, rms = 0.144728
# Step 24: cost = 1231.267209, rms = 0.144549
# Step 25: cost = 1231.088964, rms = 0.144437
# Step 26: cost = 1230.965543, rms = 0.144366
# Step 27: cost = 1230.878342, rms = 0.144322
# Step 28: cost = 1230.815907, rms = 0.144295
# Step 29: cost = 1230.770833, rms = 0.144280
# Step 30: cost = 1230.738154, rms = 0.144271
# Step 31: cost = 1230.714442, rms = 0.144267
# Step 32: cost = 1230.697275, rms = 0.144266
# Step 33: cost = 1230.684921, rms = 0.144268
# Step 34: cost = 1230.676122, rms = 0.144270
# Step 35: cost = 1230.669955, rms = 0.144273
# Step 36: cost = 1230.665738, rms = 0.144276
# Step 37: cost = 1230.662962, rms = 0.144280
# Step 38: cost = 1230.661249, rms = 0.144283
# Step 39: cost = 1230.660313, rms = 0.144287
# Step 40: cost = 1230.659943, rms = 0.144290
# Step 41: cost = 1230.659976, rms = 0.144293
# Step 42: cost = 1230.660291, rms = 0.144296
# Step 43: cost = 1230.660802, rms = 0.144299
# Step 44: cost = 1230.661436, rms = 0.144301
# Step 45: cost = 1230.662146, rms = 0.144304
# Step 46: cost = 1230.662897, rms = 0.144306
# Step 47: cost = 1230.663658, rms = 0.144308
# Step 48: cost = 1230.664413, rms = 0.144310
# Step 49: cost = 1230.665146, rms = 0.144311
# Step 50: cost = 1230.665849, rms = 0.144313
# Step 51: cost = 1230.666515, rms = 0.144314
# Step 52: cost = 1230.667141, rms = 0.144316
# Step 53: cost = 1230.667727, rms = 0.144317
# Step 54: cost = 1230.668271, rms = 0.144318
# Step 55: cost = 1230.668775, rms = 0.144319
# Step 56: cost = 1230.669238, rms = 0.144319
# Step 57: cost = 1230.669665, rms = 0.144320
# Step 58: cost = 1230.670055, rms = 0.144321
# Step 59: cost = 1230.670411, rms = 0.144321
# Step 60: cost = 1230.670735, rms = 0.144322
# Step 61: cost = 1230.671030, rms = 0.144322
# Step 62: cost = 1230.671298, rms = 0.144323
# Step 63: cost = 1230.671540, rms = 0.144323
# Step 64: cost = 1230.671764, rms = 0.144324
# Step 65: cost = 1230.671963, rms = 0.144324
# Step 66: cost = 1230.672142, rms = 0.144324
# Step 67: cost = 1230.672306, rms = 0.144325
# Step 68: cost = 1230.672452, rms = 0.144325
# Step 69: cost = 1230.672585, rms = 0.144325
# Step 70: cost = 1230.672704, rms = 0.144325
# Step 71: cost = 1230.672814, rms = 0.144325
# Step 72: cost = 1230.672910, rms = 0.144326
# Step 73: cost = 1230.672998, rms = 0.144326
# Step 74: cost = 1230.673077, rms = 0.144326
# Step 75: cost = 1230.673147, rms = 0.144326
# Step 76: cost = 1230.673211, rms = 0.144326
# Step 77: cost = 1230.673267, rms = 0.144326
# Step 78: cost = 1230.673322, rms = 0.144326
# Step 79: cost = 1230.673367, rms = 0.144326
# Step 80: cost = 1230.673408, rms = 0.144326
# Learning is finished.
# xrec:  [[-0.42474241 -0.01673014  0.44147255 ... -0.18713757 -0.18571122
#   -0.25836823]
#  [ 0.60065623 -0.00413472 -0.59652151 ... -0.02602551 -0.30636896
#    0.48322056]
#  [-0.27557577  0.00287909  0.27269669 ...  0.04160119  0.44917833
#   -0.48373044]
#  ...
#  [ 0.06554734  0.03353711 -0.09908445 ... -0.19119787 -0.20279331
#    0.61726968]
#  [-0.31140147  0.03010187  0.2812996  ... -0.11492459 -0.26492635
#    0.46049888]
#  [ 0.61726298 -0.00420525 -0.61305773 ... -0.07291486 -0.290363
#    0.45515689]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.027632058179748176
# iteration 7 out of 17
# ###############################
# Number of PCs: 9
# ###############################
# No empty rows or columns
# Step 0: rms = 0.813673
# Step 1: cost = 2120.646512, rms = 0.396117
# Step 2: cost = 1864.333271, rms = 0.386654
# Step 3: cost = 1785.073631, rms = 0.354183
# Step 4: cost = 1685.544715, rms = 0.315046
# Step 5: cost = 1608.738891, rms = 0.282632
# Step 6: cost = 1547.115836, rms = 0.257508
# Step 7: cost = 1511.390079, rms = 0.242177
# Step 8: cost = 1482.527064, rms = 0.229135
# Step 9: cost = 1461.330580, rms = 0.218810
# Step 10: cost = 1438.009084, rms = 0.207407
# Step 11: cost = 1414.583010, rms = 0.195831
# Step 12: cost = 1386.087116, rms = 0.182357
# Step 13: cost = 1352.643426, rms = 0.167844
# Step 14: cost = 1326.299245, rms = 0.156975
# Step 15: cost = 1307.626915, rms = 0.148997
# Step 16: cost = 1282.519663, rms = 0.139017
# Step 17: cost = 1255.925767, rms = 0.129473
# Step 18: cost = 1241.137967, rms = 0.124142
# Step 19: cost = 1232.832411, rms = 0.121047
# Step 20: cost = 1227.629125, rms = 0.119036
# Step 21: cost = 1224.169026, rms = 0.117669
# Step 22: cost = 1221.734975, rms = 0.116714
# Step 23: cost = 1219.936325, rms = 0.116033
# Step 24: cost = 1218.557965, rms = 0.115538
# Step 25: cost = 1217.477869, rms = 0.115172
# Step 26: cost = 1216.622772, rms = 0.114898
# Step 27: cost = 1215.944622, rms = 0.114691
# Step 28: cost = 1215.408516, rms = 0.114534
# Step 29: cost = 1214.986960, rms = 0.114416
# Step 30: cost = 1214.657353, rms = 0.114327
# Step 31: cost = 1214.400937, rms = 0.114261
# Step 32: cost = 1214.202267, rms = 0.114212
# Step 33: cost = 1214.048809, rms = 0.114177
# Step 34: cost = 1213.930543, rms = 0.114152
# Step 35: cost = 1213.839553, rms = 0.114134
# Step 36: cost = 1213.769650, rms = 0.114122
# Step 37: cost = 1213.716023, rms = 0.114114
# Step 38: cost = 1213.674951, rms = 0.114109
# Step 39: cost = 1213.643559, rms = 0.114107
# Step 40: cost = 1213.619632, rms = 0.114106
# Step 41: cost = 1213.601458, rms = 0.114106
# Step 42: cost = 1213.587723, rms = 0.114107
# Step 43: cost = 1213.577406, rms = 0.114109
# Step 44: cost = 1213.569718, rms = 0.114110
# Step 45: cost = 1213.564052, rms = 0.114112
# Step 46: cost = 1213.559940, rms = 0.114114
# Step 47: cost = 1213.557013, rms = 0.114116
# Step 48: cost = 1213.554988, rms = 0.114118
# Step 49: cost = 1213.553651, rms = 0.114120
# Step 50: cost = 1213.552827, rms = 0.114122
# Step 51: cost = 1213.552388, rms = 0.114123
# Step 52: cost = 1213.552231, rms = 0.114125
# Step 53: cost = 1213.552282, rms = 0.114126
# Step 54: cost = 1213.552475, rms = 0.114128
# Step 55: cost = 1213.552771, rms = 0.114129
# Step 56: cost = 1213.553129, rms = 0.114130
# Step 57: cost = 1213.553528, rms = 0.114131
# Step 58: cost = 1213.553945, rms = 0.114132
# Step 59: cost = 1213.554369, rms = 0.114133
# Step 60: cost = 1213.554791, rms = 0.114134
# Step 61: cost = 1213.555197, rms = 0.114134
# Step 62: cost = 1213.555586, rms = 0.114135
# Step 63: cost = 1213.555957, rms = 0.114136
# Step 64: cost = 1213.556303, rms = 0.114136
# Step 65: cost = 1213.556628, rms = 0.114137
# Step 66: cost = 1213.556929, rms = 0.114137
# Step 67: cost = 1213.557207, rms = 0.114137
# Step 68: cost = 1213.557465, rms = 0.114138
# Step 69: cost = 1213.557700, rms = 0.114138
# Step 70: cost = 1213.557914, rms = 0.114138
# Step 71: cost = 1213.558110, rms = 0.114138
# Step 72: cost = 1213.558288, rms = 0.114139
# Step 73: cost = 1213.558450, rms = 0.114139
# Step 74: cost = 1213.558597, rms = 0.114139
# Step 75: cost = 1213.558730, rms = 0.114139
# Step 76: cost = 1213.558851, rms = 0.114139
# Step 77: cost = 1213.558960, rms = 0.114140
# Step 78: cost = 1213.559059, rms = 0.114140
# Step 79: cost = 1213.559148, rms = 0.114140
# Step 80: cost = 1213.559228, rms = 0.114140
# Learning is finished.
# xrec:  [[-0.39690708 -0.01624089  0.41314798 ... -0.15049989 -0.22290197
#   -0.32472657]
#  [ 0.56865222 -0.00878568 -0.55986653 ... -0.11982185 -0.27053776
#    0.59824107]
#  [-0.32651401 -0.0012326   0.32774661 ... -0.06966001  0.51818809
#   -0.38604257]
#  ...
#  [ 0.08577958  0.03637464 -0.12215421 ... -0.15434756 -0.23153159
#    0.5948864 ]
#  [-0.34810036  0.03059613  0.31750423 ... -0.16344789 -0.25728199
#    0.53318533]
#  [ 0.58541227 -0.00626353 -0.57914874 ... -0.15635923 -0.25863854
#    0.56703507]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.030186458371711022
# iteration 8 out of 17
# ###############################
# Number of PCs: 10
# ###############################
# No empty rows or columns
# Step 0: rms = 0.881476
# Step 1: cost = 2192.399199, rms = 0.394842
# Step 2: cost = 1918.240826, rms = 0.382945
# Step 3: cost = 1824.782217, rms = 0.345932
# Step 4: cost = 1736.612720, rms = 0.310748
# Step 5: cost = 1665.387457, rms = 0.279445
# Step 6: cost = 1607.512590, rms = 0.255742
# Step 7: cost = 1577.739770, rms = 0.242349
# Step 8: cost = 1550.306607, rms = 0.229558
# Step 9: cost = 1528.981871, rms = 0.218959
# Step 10: cost = 1505.985771, rms = 0.207359
# Step 11: cost = 1480.343689, rms = 0.194408
# Step 12: cost = 1445.185728, rms = 0.177728
# Step 13: cost = 1407.643064, rms = 0.161206
# Step 14: cost = 1371.873463, rms = 0.146333
# Step 15: cost = 1334.739375, rms = 0.132359
# Step 16: cost = 1291.834701, rms = 0.117599
# Step 17: cost = 1238.881102, rms = 0.102367
# Step 18: cost = 1203.957777, rms = 0.094175
# Step 19: cost = 1182.734547, rms = 0.089691
# Step 20: cost = 1169.709357, rms = 0.086924
# Step 21: cost = 1162.054100, rms = 0.085164
# Step 22: cost = 1157.734698, rms = 0.084033
# Step 23: cost = 1155.367279, rms = 0.083300
# Step 24: cost = 1154.089139, rms = 0.082821
# Step 25: cost = 1153.400048, rms = 0.082506
# Step 26: cost = 1153.024631, rms = 0.082297
# Step 27: cost = 1152.816075, rms = 0.082158
# Step 28: cost = 1152.697248, rms = 0.082065
# Step 29: cost = 1152.627640, rms = 0.082002
# Step 30: cost = 1152.585733, rms = 0.081960
# Step 31: cost = 1152.559867, rms = 0.081932
# Step 32: cost = 1152.543555, rms = 0.081913
# Step 33: cost = 1152.533086, rms = 0.081900
# Step 34: cost = 1152.526271, rms = 0.081891
# Step 35: cost = 1152.521786, rms = 0.081885
# Step 36: cost = 1152.518809, rms = 0.081881
# Step 37: cost = 1152.516819, rms = 0.081879
# Step 38: cost = 1152.515482, rms = 0.081877
# Step 39: cost = 1152.514579, rms = 0.081876
# Step 40: cost = 1152.513968, rms = 0.081875
# Step 41: cost = 1152.513553, rms = 0.081874
# Step 42: cost = 1152.513271, rms = 0.081874
# Step 43: cost = 1152.513077, rms = 0.081873
# Step 44: cost = 1152.512945, rms = 0.081873
# Step 45: cost = 1152.512854, rms = 0.081873
# Step 46: cost = 1152.512792, rms = 0.081873
# Step 47: cost = 1152.512749, rms = 0.081873
# Step 48: cost = 1152.512720, rms = 0.081873
# Step 49: cost = 1152.512699, rms = 0.081873
# Step 50: cost = 1152.512685, rms = 0.081873
# Step 51: cost = 1152.512675, rms = 0.081873
# Step 52: cost = 1152.512669, rms = 0.081873
# Step 53: cost = 1152.512664, rms = 0.081873
# Step 54: cost = 1152.512661, rms = 0.081873
# Step 55: cost = 1152.512658, rms = 0.081873
# Step 56: cost = 1152.512657, rms = 0.081873
# Step 57: cost = 1152.512656, rms = 0.081873
# Step 58: cost = 1152.512655, rms = 0.081873
# Step 59: cost = 1152.512655, rms = 0.081873
# Step 60: cost = 1152.512654, rms = 0.081873
# Step 61: cost = 1152.512653, rms = 0.081873
# Step 62: cost = 1152.512654, rms = 0.081873
# Step 63: cost = 1152.512653, rms = 0.081873
# Step 64: cost = 1152.512654, rms = 0.081873
# Step 65: cost = 1152.512653, rms = 0.081873
# Step 66: cost = 1152.512653, rms = 0.081873
# Step 67: cost = 1152.512653, rms = 0.081873
# Step 68: cost = 1152.512653, rms = 0.081873
# Step 69: cost = 1152.512653, rms = 0.081873
# Step 70: cost = 1152.512653, rms = 0.081873
# Step 71: cost = 1152.512653, rms = 0.081873
# Step 72: cost = 1152.512653, rms = 0.081873
# Step 73: cost = 1152.512653, rms = 0.081873
# Step 74: cost = 1152.512653, rms = 0.081873
# Step 75: cost = 1152.512653, rms = 0.081873
# Step 76: cost = 1152.512653, rms = 0.081873
# Step 77: cost = 1152.512653, rms = 0.081873
# Step 78: cost = 1152.512653, rms = 0.081873
# Step 79: cost = 1152.512653, rms = 0.081873
# Step 80: cost = 1152.512653, rms = 0.081873
# Learning is finished.
# xrec:  [[-0.39733261 -0.01875142  0.41608403 ... -0.16482293 -0.23610209
#   -0.33162914]
#  [ 0.58179472 -0.01940707 -0.56238764 ... -0.14960428 -0.25408317
#    0.6201425 ]
#  [-0.36211792 -0.05782175  0.41993967 ... -0.13706401  0.67189228
#   -0.34202429]
#  ...
#  [ 0.09783609  0.05163315 -0.14946923 ... -0.13688854 -0.27986837
#    0.59691917]
#  [-0.37412398  0.01825203  0.35587195 ... -0.1808765  -0.23566407
#    0.57440764]
#  [ 0.59359876 -0.01477754 -0.57882122 ... -0.17214607 -0.24596526
#    0.59461975]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.032267095146169
# iteration 9 out of 17
# ###############################
# Number of PCs: 11
# ###############################
# No empty rows or columns
# Step 0: rms = 0.850444
# Step 1: cost = 2258.926616, rms = 0.393178
# Step 2: cost = 1983.373692, rms = 0.384928
# Step 3: cost = 1898.433530, rms = 0.351134
# Step 4: cost = 1809.663771, rms = 0.315079
# Step 5: cost = 1741.009941, rms = 0.284675
# Step 6: cost = 1681.269528, rms = 0.258860
# Step 7: cost = 1642.901737, rms = 0.241870
# Step 8: cost = 1614.673441, rms = 0.228483
# Step 9: cost = 1593.397556, rms = 0.217554
# Step 10: cost = 1570.877508, rms = 0.205939
# Step 11: cost = 1547.139142, rms = 0.193563
# Step 12: cost = 1515.556233, rms = 0.178171
# Step 13: cost = 1482.657653, rms = 0.163174
# Step 14: cost = 1451.409318, rms = 0.149515
# Step 15: cost = 1412.752380, rms = 0.134139
# Step 16: cost = 1365.365800, rms = 0.117287
# Step 17: cost = 1316.637911, rms = 0.102862
# Step 18: cost = 1284.451620, rms = 0.094997
# Step 19: cost = 1263.872408, rms = 0.090421
# Step 20: cost = 1250.437688, rms = 0.087387
# Step 21: cost = 1237.319811, rms = 0.084063
# Step 22: cost = 1194.655004, rms = 0.073490
# Step 23: cost = 1128.140655, rms = 0.060553
# Step 24: cost = 1093.464859, rms = 0.056116
# Step 25: cost = 1071.250426, rms = 0.053847
# Step 26: cost = 1056.511103, rms = 0.052430
# Step 27: cost = 1047.136286, rms = 0.051514
# Step 28: cost = 1041.416605, rms = 0.050910
# Step 29: cost = 1038.043244, rms = 0.050505
# Step 30: cost = 1036.102193, rms = 0.050230
# Step 31: cost = 1035.002248, rms = 0.050041
# Step 32: cost = 1034.382834, rms = 0.049909
# Step 33: cost = 1034.033281, rms = 0.049817
# Step 34: cost = 1033.834096, rms = 0.049752
# Step 35: cost = 1033.718742, rms = 0.049707
# Step 36: cost = 1033.650506, rms = 0.049675
# Step 37: cost = 1033.609142, rms = 0.049652
# Step 38: cost = 1033.583416, rms = 0.049636
# Step 39: cost = 1033.567012, rms = 0.049624
# Step 40: cost = 1033.556311, rms = 0.049616
# Step 41: cost = 1033.549191, rms = 0.049610
# Step 42: cost = 1033.544377, rms = 0.049606
# Step 43: cost = 1033.541078, rms = 0.049603
# Step 44: cost = 1033.538797, rms = 0.049601
# Step 45: cost = 1033.537206, rms = 0.049599
# Step 46: cost = 1033.536090, rms = 0.049598
# Step 47: cost = 1033.535305, rms = 0.049598
# Step 48: cost = 1033.534750, rms = 0.049597
# Step 49: cost = 1033.534358, rms = 0.049597
# Step 50: cost = 1033.534080, rms = 0.049596
# Step 51: cost = 1033.533883, rms = 0.049596
# Step 52: cost = 1033.533742, rms = 0.049596
# Step 53: cost = 1033.533643, rms = 0.049596
# Step 54: cost = 1033.533572, rms = 0.049596
# Step 55: cost = 1033.533522, rms = 0.049596
# Step 56: cost = 1033.533486, rms = 0.049596
# Step 57: cost = 1033.533460, rms = 0.049596
# Step 58: cost = 1033.533442, rms = 0.049596
# Step 59: cost = 1033.533429, rms = 0.049596
# Step 60: cost = 1033.533420, rms = 0.049596
# Step 61: cost = 1033.533413, rms = 0.049596
# Step 62: cost = 1033.533409, rms = 0.049596
# Step 63: cost = 1033.533406, rms = 0.049596
# Step 64: cost = 1033.533403, rms = 0.049596
# Step 65: cost = 1033.533401, rms = 0.049596
# Step 66: cost = 1033.533400, rms = 0.049596
# Step 67: cost = 1033.533399, rms = 0.049596
# Step 68: cost = 1033.533399, rms = 0.049596
# Step 69: cost = 1033.533398, rms = 0.049596
# Step 70: cost = 1033.533398, rms = 0.049596
# Step 71: cost = 1033.533398, rms = 0.049596
# Step 72: cost = 1033.533398, rms = 0.049596
# Step 73: cost = 1033.533398, rms = 0.049596
# Step 74: cost = 1033.533398, rms = 0.049596
# Step 75: cost = 1033.533397, rms = 0.049596
# Step 76: cost = 1033.533397, rms = 0.049596
# Step 77: cost = 1033.533397, rms = 0.049596
# Step 78: cost = 1033.533397, rms = 0.049596
# Step 79: cost = 1033.533397, rms = 0.049596
# Step 80: cost = 1033.533398, rms = 0.049596
# Learning is finished.
# xrec:  [[-0.38183392 -0.02690543  0.40873935 ... -0.18046582 -0.24101157
#   -0.3630418 ]
#  [ 0.61045137 -0.03190027 -0.5785511  ... -0.17197649 -0.24939486
#    0.61289   ]
#  [-0.34765501 -0.07690098  0.42455599 ... -0.16636837  0.71640129
#   -0.37191357]
#  ...
#  [ 0.09391484  0.05864117 -0.15255601 ... -0.12945351 -0.29780863
#    0.61655556]
#  [-0.39380294  0.02002021  0.37378274 ... -0.18598473 -0.2433362
#    0.60778631]
#  [ 0.60586089 -0.01851202 -0.58734887 ... -0.18071753 -0.24790234
#    0.61030472]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.03227695268290196
# iteration 10 out of 17
# ...
# Step 41: cost = 1121.223434, rms = 0.049745
# Step 42: cost = 1121.211992, rms = 0.049737
# Step 43: cost = 1121.203070, rms = 0.049730
# Step 44: cost = 1121.190154, rms = 0.049724
# Step 45: cost = 1121.142830, rms = 0.049711
# Step 46: cost = 1120.893016, rms = 0.049653
# Step 47: cost = 1119.516650, rms = 0.049347
# Step 48: cost = 1112.738728, rms = 0.047855
# Step 49: cost = 1092.856243, rms = 0.043577
# Step 50: cost = 1073.957803, rms = 0.039597
# Step 51: cost = 1065.252174, rms = 0.038013
# Step 52: cost = 1059.804206, rms = 0.037255
# Step 53: cost = 1055.888665, rms = 0.036744
# Step 54: cost = 1053.044530, rms = 0.036359
# Step 55: cost = 1050.973446, rms = 0.036060
# Step 56: cost = 1049.456511, rms = 0.035825
# Step 57: cost = 1048.334882, rms = 0.035638
# Step 58: cost = 1047.495371, rms = 0.035489
# Step 59: cost = 1046.858320, rms = 0.035370
# Step 60: cost = 1046.367986, rms = 0.035274
# Step 61: cost = 1045.985348, rms = 0.035196
# Step 62: cost = 1045.682939, rms = 0.035133
# Step 63: cost = 1045.441234, rms = 0.035081
# Step 64: cost = 1045.246172, rms = 0.035040
# Step 65: cost = 1045.087472, rms = 0.035005
# Step 66: cost = 1044.957491, rms = 0.034977
# Step 67: cost = 1044.850454, rms = 0.034954
# Step 68: cost = 1044.761925, rms = 0.034936
# Step 69: cost = 1044.688449, rms = 0.034920
# Step 70: cost = 1044.627298, rms = 0.034907
# Step 71: cost = 1044.576293, rms = 0.034897
# Step 72: cost = 1044.533678, rms = 0.034888
# Step 73: cost = 1044.498027, rms = 0.034881
# Step 74: cost = 1044.468171, rms = 0.034875
# Step 75: cost = 1044.443150, rms = 0.034870
# Step 76: cost = 1044.422171, rms = 0.034866
# Step 77: cost = 1044.404574, rms = 0.034863
# Step 78: cost = 1044.389813, rms = 0.034860
# Step 79: cost = 1044.377431, rms = 0.034857
# Step 80: cost = 1044.367047, rms = 0.034855
# Learning is finished.
# xrec:  [[-0.38207607 -0.02644663  0.40852271 ... -0.18351878 -0.24479022
#   -0.36637892]
#  [ 0.62467059 -0.05074857 -0.57392201 ... -0.17750374 -0.25158451
#    0.61995794]
#  [-0.34835527 -0.08153142  0.42988669 ... -0.17288456  0.72730996
#   -0.37200002]
#  ...
#  [ 0.05957735  0.12307132 -0.18264867 ... -0.12603732 -0.29953788
#    0.61354293]
#  [-0.39882328  0.02032237  0.37850091 ... -0.18849886 -0.2448812
#    0.61615528]
#  [ 0.61702845 -0.03343201 -0.58359644 ... -0.18345018 -0.24998857
#    0.61828944]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.014740291591335455
# iteration 11 out of 17
# ###############################
# Number of PCs: 13
# ###############################
# No empty rows or columns
# Step 0: rms = 0.947004
# Step 1: cost = 2414.574443, rms = 0.395872
# Step 2: cost = 2103.452965, rms = 0.382961
# Step 3: cost = 2016.215238, rms = 0.349800
# Step 4: cost = 1936.655800, rms = 0.315634
# Step 5: cost = 1863.697520, rms = 0.282138
# Step 6: cost = 1806.658659, rms = 0.256974
# Step 7: cost = 1773.449259, rms = 0.241457
# Step 8: cost = 1749.988296, rms = 0.229783
# Step 9: cost = 1734.591176, rms = 0.221258
# Step 10: cost = 1716.812064, rms = 0.211502
# Step 11: cost = 1697.753228, rms = 0.200996
# Step 12: cost = 1674.310755, rms = 0.188257
# Step 13: cost = 1643.291916, rms = 0.172727
# Step 14: cost = 1614.300099, rms = 0.158789
# Step 15: cost = 1582.781641, rms = 0.144642
# Step 16: cost = 1547.886756, rms = 0.130313
# Step 17: cost = 1505.512803, rms = 0.114719
# Step 18: cost = 1464.939538, rms = 0.102222
# Step 19: cost = 1438.609320, rms = 0.095292
# Step 20: cost = 1421.387190, rms = 0.091059
# Step 21: cost = 1410.040607, rms = 0.088213
# Step 22: cost = 1400.403459, rms = 0.085567
# Step 23: cost = 1374.051005, rms = 0.078355
# Step 24: cost = 1311.781141, rms = 0.064126
# Step 25: cost = 1274.060941, rms = 0.057999
# Step 26: cost = 1251.433090, rms = 0.055243
# Step 27: cost = 1235.902835, rms = 0.053518
# Step 28: cost = 1225.540647, rms = 0.052380
# Step 29: cost = 1218.885698, rms = 0.051614
# Step 30: cost = 1214.752224, rms = 0.051091
# Step 31: cost = 1212.251319, rms = 0.050729
# Step 32: cost = 1210.765740, rms = 0.050476
# Step 33: cost = 1209.892582, rms = 0.050297
# Step 34: cost = 1209.381008, rms = 0.050170
# Step 35: cost = 1209.080179, rms = 0.050079
# Step 36: cost = 1208.901532, rms = 0.050013
# Step 37: cost = 1208.793842, rms = 0.049966
# Step 38: cost = 1208.727683, rms = 0.049932
# Step 39: cost = 1208.686158, rms = 0.049908
# Step 40: cost = 1208.659505, rms = 0.049890
# Step 41: cost = 1208.642011, rms = 0.049877
# Step 42: cost = 1208.630247, rms = 0.049867
# Step 43: cost = 1208.621917, rms = 0.049860
# Step 44: cost = 1208.614431, rms = 0.049855
# Step 45: cost = 1208.599718, rms = 0.049849
# Step 46: cost = 1208.537097, rms = 0.049832
# Step 47: cost = 1208.204831, rms = 0.049754
# Step 48: cost = 1206.429506, rms = 0.049345
# Step 49: cost = 1198.284449, rms = 0.047490
# Step 50: cost = 1177.866437, rms = 0.042925
# Step 51: cost = 1161.087982, rms = 0.039218
# Step 52: cost = 1150.053946, rms = 0.037041
# Step 53: cost = 1124.803397, rms = 0.032111
# Step 54: cost = 1072.690582, rms = 0.022418
# Step 55: cost = 1031.804748, rms = 0.016817
# Step 56: cost = 995.902549, rms = 0.013803
# Step 57: cost = 959.954248, rms = 0.011473
# Step 58: cost = 923.770337, rms = 0.009543
# Step 59: cost = 887.386955, rms = 0.007936
# Step 60: cost = 850.843079, rms = 0.006598
# Step 61: cost = 814.171927, rms = 0.005484
# Step 62: cost = 777.401719, rms = 0.004557
# Step 63: cost = 740.556843, rms = 0.003786
# Step 64: cost = 703.658859, rms = 0.003146
# Step 65: cost = 666.727344, rms = 0.002613
# Step 66: cost = 629.780621, rms = 0.002171
# Step 67: cost = 592.836416, rms = 0.001804
# Step 68: cost = 555.912479, rms = 0.001499
# Step 69: cost = 519.027191, rms = 0.001246
# Step 70: cost = 482.200178, rms = 0.001037
# Step 71: cost = 445.452947, rms = 0.000862
# Step 72: cost = 408.809568, rms = 0.000718
# Step 73: cost = 372.297413, rms = 0.000598
# Step 74: cost = 335.947955, rms = 0.000498
# Step 75: cost = 299.797650, rms = 0.000416
# Step 76: cost = 263.888892, rms = 0.000348
# Step 77: cost = 228.271027, rms = 0.000291
# Step 78: cost = 193.001422, rms = 0.000244
# Step 79: cost = 158.146534, rms = 0.000205
# Step 80: cost = 123.782902, rms = 0.000172
# Learning is finished.
# xrec:  [[-0.38804464 -0.01495484  0.40299949 ... -0.1893318  -0.24992903
#   -0.37115185]
#  [ 0.61188954 -0.0149681  -0.59692145 ... -0.18928142 -0.24999136
#    0.62868641]
#  [-0.38792055 -0.01507735  0.4029979  ... -0.18924837  0.74977254
#   -0.3712135 ]
#  ...
#  [-0.38664681  0.9823338  -0.59568699 ... -0.18923226 -0.25008435
#    0.62869732]
#  [-0.38801975 -0.01482422  0.40284396 ... -0.18935618 -0.24996135
#    0.62863029]
#  [ 0.61188941 -0.01493515 -0.59695426 ... -0.18933907 -0.24998448
#    0.62866365]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: -0.03468315040775299
# iteration 12 out of 17
# ###############################
# Number of PCs: 14
# ###############################
# No empty rows or columns
# Step 0: rms = 0.973677
# Step 1: cost = 2481.590857, rms = 0.394774
# Step 2: cost = 2164.860121, rms = 0.382810
# Step 3: cost = 2077.106304, rms = 0.349536
# Step 4: cost = 1997.637127, rms = 0.315340
# Step 5: cost = 1931.062278, rms = 0.284238
# Step 6: cost = 1877.266642, rms = 0.259885
# Step 7: cost = 1846.892663, rms = 0.245389
# Step 8: cost = 1822.438369, rms = 0.232866
# Step 9: cost = 1803.649791, rms = 0.222671
# Step 10: cost = 1785.846043, rms = 0.212618
# Step 11: cost = 1768.295119, rms = 0.202599
# Step 12: cost = 1748.264772, rms = 0.191245
# Step 13: cost = 1720.962616, rms = 0.176900
# Step 14: cost = 1692.332403, rms = 0.162561
# Step 15: cost = 1662.930701, rms = 0.148557
# Step 16: cost = 1629.339946, rms = 0.133923
# Step 17: cost = 1589.931609, rms = 0.118433
# Step 18: cost = 1550.107376, rms = 0.105145
# Step 19: cost = 1522.837601, rms = 0.097387
# Step 20: cost = 1504.686108, rms = 0.092643
# Step 21: cost = 1492.400526, rms = 0.089418
# Step 22: cost = 1481.685510, rms = 0.086374
# Step 23: cost = 1454.593397, rms = 0.078664
# Step 24: cost = 1397.112428, rms = 0.064913
# Step 25: cost = 1361.793461, rms = 0.058798
# Step 26: cost = 1339.815327, rms = 0.055903
# Step 27: cost = 1324.424511, rms = 0.054061
# Step 28: cost = 1313.934351, rms = 0.052829
# Step 29: cost = 1307.042011, rms = 0.051990
# Step 30: cost = 1302.658999, rms = 0.051411
# Step 31: cost = 1299.943770, rms = 0.051007
# Step 32: cost = 1298.293442, rms = 0.050721
# Step 33: cost = 1297.302199, rms = 0.050517
# Step 34: cost = 1296.709776, rms = 0.050371
# Step 35: cost = 1296.355192, rms = 0.050265
# Step 36: cost = 1296.141407, rms = 0.050189
# Step 37: cost = 1296.010914, rms = 0.050133
# Step 38: cost = 1295.929946, rms = 0.050092
# Step 39: cost = 1295.878735, rms = 0.050063
# Step 40: cost = 1295.845672, rms = 0.050041
# Step 41: cost = 1295.823876, rms = 0.050025
# Step 42: cost = 1295.809209, rms = 0.050013
# Step 43: cost = 1295.799081, rms = 0.050005
# Step 44: cost = 1295.791561, rms = 0.049998
# Step 45: cost = 1295.783800, rms = 0.049993
# Step 46: cost = 1295.765618, rms = 0.049986
# Step 47: cost = 1295.687307, rms = 0.049965
# Step 48: cost = 1295.294020, rms = 0.049869
# Step 49: cost = 1293.310873, rms = 0.049389
# Step 50: cost = 1284.409570, rms = 0.047247
# Step 51: cost = 1258.544936, rms = 0.041006
# Step 52: cost = 1219.959634, rms = 0.031633
# Step 53: cost = 1181.798045, rms = 0.023655
# Step 54: cost = 1148.910551, rms = 0.019062
# Step 55: cost = 1116.786421, rms = 0.015911
# Step 56: cost = 1084.424817, rms = 0.013360
# Step 57: cost = 1051.805337, rms = 0.011222
# Step 58: cost = 1018.971179, rms = 0.009423
# Step 59: cost = 985.962117, rms = 0.007910
# Step 60: cost = 952.811411, rms = 0.006637
# Step 61: cost = 919.547050, rms = 0.005568
# Step 62: cost = 886.192973, rms = 0.004670
# Step 63: cost = 852.770032, rms = 0.003916
# Step 64: cost = 819.296766, rms = 0.003284
# Step 65: cost = 785.790050, rms = 0.002754
# Step 66: cost = 752.265657, rms = 0.002309
# Step 67: cost = 718.738764, rms = 0.001936
# Step 68: cost = 685.224432, rms = 0.001624
# Step 69: cost = 651.738065, rms = 0.001362
# Step 70: cost = 618.295881, rms = 0.001143
# Step 71: cost = 584.915380, rms = 0.000960
# Step 72: cost = 551.615857, rms = 0.000806
# Step 73: cost = 518.418935, rms = 0.000677
# Step 74: cost = 485.349151, rms = 0.000569
# Step 75: cost = 452.434582, rms = 0.000479
# Step 76: cost = 419.707535, rms = 0.000404
# Step 77: cost = 387.205275, rms = 0.000340
# Step 78: cost = 354.970799, rms = 0.000288
# Step 79: cost = 323.053630, rms = 0.000243
# Step 80: cost = 291.510591, rms = 0.000206
# Learning is finished.
# xrec:  [[-0.38804169 -0.01496062  0.40300231 ... -0.1893196  -0.2499151
#   -0.37114002]
#  [ 0.61187958 -0.01497648 -0.5969031  ... -0.18925933 -0.24998966
#    0.62866649]
#  [-0.38789325 -0.01510718  0.40300042 ... -0.1892198   0.7497279
#   -0.37121377]
#  ...
#  [-0.38636934  0.98179556 -0.59542621 ... -0.18920051 -0.25010091
#    0.62867954]
#  [-0.38801191 -0.01480435  0.40281626 ... -0.18934877 -0.24995377
#    0.62859936]
#  [ 0.61187942 -0.01493706 -0.59694236 ... -0.18932831 -0.24998143
#    0.62863926]]
# MnInit:  [[0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  ...
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]
#  [0.3880597  0.01492537 0.59701493 ... 0.18939394 0.25       0.37121212]]
# Number of non-matching elements (accu_num): 2342
# Total number of elements in X_: 2342
# Calculated accuracy: 0.0
# Improvement: 3.384033259115979e-05
# Breaking loop early due to positive improvement.
# No empty rows or columns
# Step 0: rms = 0.932604
# Step 1: cost = 2405.281351, rms = 0.393501
# Step 2: cost = 2104.037631, rms = 0.383641
# Step 3: cost = 2020.245388, rms = 0.352022
# Step 4: cost = 1946.863914, rms = 0.320369
# Step 5: cost = 1871.504627, rms = 0.285471
# Step 6: cost = 1811.615582, rms = 0.259288
# Step 7: cost = 1778.724189, rms = 0.244055
# Step 8: cost = 1753.609485, rms = 0.231575
# Step 9: cost = 1735.824893, rms = 0.222012
# Step 10: cost = 1717.223449, rms = 0.211785
# Step 11: cost = 1696.916101, rms = 0.200639
# Step 12: cost = 1672.242862, rms = 0.187333
# Step 13: cost = 1641.606265, rms = 0.172037
# Step 14: cost = 1614.239921, rms = 0.158881
# Step 15: cost = 1585.237750, rms = 0.145727
# Step 16: cost = 1551.606101, rms = 0.131863
# Step 17: cost = 1512.100699, rms = 0.117018
# Step 18: cost = 1469.606040, rms = 0.103552
# Step 19: cost = 1441.285292, rms = 0.095964
# Step 20: cost = 1423.074925, rms = 0.091471
# Step 21: cost = 1411.071962, rms = 0.088474
# Step 22: cost = 1400.884713, rms = 0.085694
# Step 23: cost = 1373.704008, rms = 0.078251
# Step 24: cost = 1311.732033, rms = 0.064091
# Step 25: cost = 1274.335348, rms = 0.058032
# Step 26: cost = 1251.652489, rms = 0.055268
# Step 27: cost = 1236.056140, rms = 0.053535
# Step 28: cost = 1225.641769, rms = 0.052391
# Step 29: cost = 1218.949657, rms = 0.051622
# Step 30: cost = 1214.791408, rms = 0.051096
# Step 31: cost = 1212.274781, rms = 0.050733
# Step 32: cost = 1210.779585, rms = 0.050479
# Step 33: cost = 1209.900698, rms = 0.050299
# Step 34: cost = 1209.385768, rms = 0.050171
# Step 35: cost = 1209.082990, rms = 0.050080
# Step 36: cost = 1208.903214, rms = 0.050014
# Step 37: cost = 1208.794865, rms = 0.049967
# Step 38: cost = 1208.728318, rms = 0.049933
# Step 39: cost = 1208.686559, rms = 0.049908
# Step 40: cost = 1208.659754, rms = 0.049890
# Step 41: cost = 1208.642119, rms = 0.049877
# Step 42: cost = 1208.630009, rms = 0.049867
# Step 43: cost = 1208.620083, rms = 0.049860
# Step 44: cost = 1208.604076, rms = 0.049853
# Step 45: cost = 1208.542747, rms = 0.049836
# Step 46: cost = 1208.223896, rms = 0.049760
# Step 47: cost = 1206.504589, rms = 0.049362
# Step 48: cost = 1198.011269, rms = 0.047411
# Step 49: cost = 1169.807133, rms = 0.040935
# Step 50: cost = 1125.479746, rms = 0.030718
# Step 51: cost = 1083.978397, rms = 0.022646
# Step 52: cost = 1047.914034, rms = 0.018138
# Step 53: cost = 1012.388258, rms = 0.015012
# Step 54: cost = 976.586438, rms = 0.012488
# Step 55: cost = 940.512751, rms = 0.010390
# Step 56: cost = 904.216971, rms = 0.008642
# Step 57: cost = 867.742877, rms = 0.007186
# Step 58: cost = 831.126768, rms = 0.005973
# Step 59: cost = 794.399090, rms = 0.004964
# Step 60: cost = 757.585881, rms = 0.004125
# Step 61: cost = 720.709897, rms = 0.003427
# Step 62: cost = 683.791537, rms = 0.002847
# Step 63: cost = 646.849615, rms = 0.002365
# Step 64: cost = 609.902056, rms = 0.001965
# Step 65: cost = 572.966524, rms = 0.001633
# Step 66: cost = 536.061033, rms = 0.001357
# Step 67: cost = 499.204555, rms = 0.001129
# Step 68: cost = 462.417648, rms = 0.000939
# Step 69: cost = 425.723109, rms = 0.000781
# Step 70: cost = 389.146689, rms = 0.000651
# Step 71: cost = 352.717862, rms = 0.000542
# Step 72: cost = 316.470669, rms = 0.000452
# Step 73: cost = 280.444636, rms = 0.000378
# Step 74: cost = 244.685769, rms = 0.000316
# Step 75: cost = 209.247595, rms = 0.000264
# Step 76: cost = 174.192241, rms = 0.000222
# Step 77: cost = 139.591472, rms = 0.000187
# Step 78: cost = 105.527616, rms = 0.000157
# Step 79: cost = 72.094243, rms = 0.000133
# Step 80: cost = 39.396434, rms = 0.000113
