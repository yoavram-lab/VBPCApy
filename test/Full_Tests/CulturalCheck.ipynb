# %%
import sys
import os
sys.path.append(os.path.abspath("../../src/vbpca_py"))

from pca_full import pca_full

# %%
import subprocess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time


# Ensure reproducibility
np.random.seed(42)

# Define the OHspecial_transform function
def OHspecial_transform(df):
    names = df.columns.values
    data = df.values
    labels = []
    
    for j in range(len(names)):
        col_data = data[:, j]
        temp = np.unique(col_data[~np.isnan(col_data)])
        temp = temp[temp >= 0]
        
        if len(temp) == 0:
            # All data in column j is NaN or negative
            var = col_data.reshape(-1, 1)
            label = [names[j]]
        elif len(temp) <= 2:
            # Keep original data
            var = col_data.reshape(-1, 1)
            label = [names[j]]
        else:
            # One-hot encode
            var = np.zeros((data.shape[0], len(temp)))
            for l in range(len(temp)):
                var[:, l] = np.where(col_data == temp[l], 1, 0)
            idx = np.where(np.isnan(col_data))[0]
            var[idx, :] = np.nan
            # Use str instead of int to match MATLAB's num2str behavior
            label = [f"{names[j]}_{str(temp[l])}" for l in range(len(temp))]
        
        if j == 0:
            OH = var
        else:
            OH = np.hstack((OH, var))
        labels.extend(label)
    
    OH_df = pd.DataFrame(OH, columns=labels)
    OH_df.to_parquet("OHspecial_transformed_iso_data.parquet")
    return OH_df

# Read in data and remove non-cultural features + features missing > 50% of possible values

# From EA
KinOrgRaw = pd.read_csv('KinshipOrgDataRaw.csv')
SubRaw = pd.read_csv('SubsistenceDataRaw.csv')
# EA_All_Raw = pd.read_csv('EA_All.csv')  # Commented out in MATLAB code

# From Pulotu
IsoRaw = pd.read_csv('IsoDataRaw.csv')
ReligRaw = pd.read_csv('RelDataRaw.csv')

# Other datasets
Binford = pd.read_csv('Binford_all.csv')
Seshat = pd.read_csv('Seshat.csv')
Birds = pd.read_csv('data_birds_OH.csv')

# Apply OHspecial_transform to datasets
KinOrg = OHspecial_transform(KinOrgRaw)
Sub = OHspecial_transform(SubRaw)
Iso = OHspecial_transform(IsoRaw)
Relig = OHspecial_transform(ReligRaw)

for w in range(4, 5):

    if w == 1:
        X = KinOrg
    elif w == 2:
        X = Sub
    elif w == 3:
        X = Relig
    elif w == 4:
        X = Iso
    elif w == 5:
        X = Binford
    elif w == 6:
        X = Seshat
    elif w == 7:
        X = Birds

    # Remove features missing > 50% of their entries
    dim = X.shape
    X = X.iloc[:, 0:dim[1]]  # Redundant but kept for similarity
    cols = X.columns.values
    X = X.to_numpy()

    counts = []
    for j in range(dim[1]):
        temp = np.isnan(X[:, j]).astype(int)
        idx = np.where(temp == 1)[0]
        counts.append(len(idx))

    counts = np.array(counts) / dim[0]
    idx = np.where(counts > 0.5)[0]
    cols = np.delete(cols, idx)
    X = np.delete(X, idx, axis=1)
    dim = X.shape

    # Compute initial mean and standard deviation, ignoring NaNs
    MnInit = np.tile(np.nanmean(X, axis=0), (dim[0], 1))
    STDInit = np.tile(np.nanstd(X, axis=0), (dim[0], 1))

    if w < 5:
        X_ = X - MnInit
    elif w == 5:
        X_ = X
    elif w == 6:
        X_ = (X - MnInit) / STDInit
    elif w == 7:
        X_ = X

    X_ = X_.T

    MaxStop = min(dim)
    if MaxStop > 100:
        MaxStop = 100
    zz = np.arange(2, MaxStop + 1)

    # Initialize lists for dynamic data collection
    rms = []
    accu = []
    rmsA = []
    costA = []
    var_exp = []
    # X_start = pd.DataFrame(X_).to_numpy(copy=True)
    # X_start = np.copy(X_)
    # pd.DataFrame(X_).to_csv("python_X_before_for.csv", index=False)
    print(f"NaN count in X_ before for (", np.isnan(X_).sum())
    # print(f"NaN count in X_start before for (", np.isnan(X_start).sum())

    for y in range(MaxStop - 1):
        print (f"iteration {y} out of {MaxStop - 1}")

        z = zz[y]
        print('###############################')
        print(f'Number of PCs: {z}')
        print('###############################')
        if y > 0:
            time.sleep(1)

        for k in range(1):  # Change if you want to do replications

            opts = {
                'maxiters': 80,
                'algorithm': 'vb',
                'uniquesv': 0,
                'rmsstop': [80, np.finfo(float).eps, np.finfo(float).eps],
                'cfstop': [80, 0, 0],
                'minangle': 0
            }

            result = pca_full(np.copy(X_), z, **opts)
            A = result['A']
            S = result['S']
            Mu = result['Mu']
            V = result['V']
            cv = result['cv']
            hp = result['hp']
            lc = result['lc']

            if z == 20:
                plt.figure()
                plt.scatter(S[0, :], S[1, :])
                plt.title('Scatter plot of first two PCs')
                plt.show()

            print('Learning is finished.')

            Xrec = Mu + A @ S
            
            accu_num = np.abs(np.round(Xrec.T + MnInit) - X_.T)
            accu_num = len(np.where(accu_num > 0)[0])
        
            # diff = np.round(Xrec.T + MnInit) - X_.T
            print("xrec: ", Xrec.T)
            print("MnInit: ", MnInit)
            print(f"Number of non-matching elements (accu_num): {accu_num}")
        
            total_elements = len(np.where(~np.isnan(X_.flatten()))[0])
            print(f"Total number of elements in X_: {total_elements}")
        
            accu_value = 1 - accu_num / total_elements
            print(f"Calculated accuracy: {accu_value}")
            # accu_value = 1 - accu_num / len(np.where(~np.isnan(X_.flatten()))[0])
            accu.append(accu_value)

            # Record rms and append lc['rms'] and lc['cost']
            rms_value = lc['rms'][-1]
            rms.append(rms_value)
            rmsA.append(lc['rms'])
            costA.append(lc['cost'])

            # Compute explained variance
            vv = np.zeros(MaxStop)
            v = np.linalg.eigvals(np.cov(Xrec))
            v = np.flipud(np.sort(np.real(v)))
            v = v[:MaxStop]
            v = np.round(v, 4)
            v = v / np.sum(v)
            vv[:len(v)] = v
            var_exp.append(vv)

        print(f"Improvement: {rms[y] - rms[y - 1]}")
        if y > 0 and (rms[y] - rms[y - 1]) > 0:
            print("Breaking loop early due to positive improvement.")
            break

    # After the loop, convert lists to NumPy arrays
    rmsA.append(lc['rms'][-1])
    costA.append(lc['cost'][-1])

    var_exp = np.array(var_exp)
    rms = np.array(rms)
    accu = np.array(accu)

    # Since w == 7
    result = pca_full(X_, zz[y - 1], **opts)
    AFin = np.array(result['A'])
    SFin = np.array(result['S'])
    MuFin = np.array(result['Mu']).flatten()
    VFin = result['V']
    cvFin = result['cv']
    hpFin = result['hp']
    lcFin = result['lc']
    Xrec = MuFin[:, np.newaxis] + AFin @ SFin

    # Compute Vr
    Vr = np.zeros_like(X_)
    for i in range(X_.shape[0]):
        for j in range(X_.shape[1]):
            Vr[i, j] = (AFin[i, :] @ cvFin['S'][j] @ AFin[i, :].T +
                        SFin[:, j].T @ cvFin['A'][i] @ SFin[:, j] +
                        np.sum(cvFin['S'][j] * cvFin['A'][i]) +
                        cvFin['Mu'][i])
    VrFin = Vr

    # Save reconstructed data
    T = pd.DataFrame(Xrec.T, columns=cols)
    T.to_csv('Finch_VBPCA_Recon_All.csv', index=False)
    XrecFin = Xrec
    rmsFin = rms
    rmsAFin = rmsA
    costAFin = costA
    var_exp_Fin = var_exp
    accu_Fin = accu

    # Plot scatter of the first two PCs
    plt.figure()
    plt.scatter(SFin[0, :], SFin[1, :], c='b', marker='o')
    plt.title('Isolation')
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.show()

    # Plot Accuracy and RMS vs Number of PCs
    plt.figure()
    fig, ax1 = plt.subplots()
    
    # Plot Accuracy on the left y-axis
    color = 'tab:blue'
    ax1.set_xlabel('Number of PCs')
    ax1.set_ylabel('Accuracy', color=color)
    x_values = np.arange(2, len(accu_Fin) + 2)
    ax1.plot(x_values, accu_Fin, color=color, linewidth=2, marker='o')
    ax1.tick_params(axis='y', labelcolor=color)
    
    # Plot RMS on the right y-axis
    ax2 = ax1.twinx()
    color = 'tab:red'
    ax2.set_ylabel('RMS', color=color)
    ax2.plot(x_values, rmsFin, color=color, linewidth=2, marker='o')
    ax2.tick_params(axis='y', labelcolor=color)
    
    # Add a vertical line at the final number of PCs
    ax1.axvline(x=len(accu_Fin) + 1, linewidth=2, color='black')
    
    # Set x-axis limits
    ax1.set_xlim([2, len(accu_Fin) + 1])
    
    # Add grid, title, and adjust font size
    ax1.grid(True)
    plt.title(r'Conflict \& Contact')
    plt.rcParams.update({'font.size': 18})
    
    # Show the plot
    plt.show()

    # Clear variables (optional in Python, but included for completeness)
    del rmsA
    del costA
    del var_exp
    del Vr
    del accu
# Out:
# NaN count in X_ before for ( 124
# iteration 0 out of 17
# ###############################
# Number of PCs: 2
# ###############################
# in pca full
# 2025-01-23T19:00:01.262804 - Starting section 3
# 2025-01-23T19:00:01.262824 - Starting section 4
# in argschk
# 2025-01-23T19:00:01.263005 - Starting section 5
# 2025-01-23T19:00:01.263017 - Starting section 6
# in rmempty
# No empty rows or columns
# 2025-01-23T19:00:01.263394 - Starting section 7
# 2025-01-23T19:00:01.263494 - Starting section 8
# 2025-01-23T19:00:01.263501 - Starting section 9
# in init_parms
# 2025-01-23T19:00:01.264045 - Starting section 10
# 2025-01-23T19:00:01.264159 - Starting section 11
# in subtract mu
# 2025-01-23T19:00:01.264404 - Starting section 12
# in compute rms
# 2025-01-23T19:00:01.264696 - Starting section 13
# in compute rms
# 2025-01-23T19:00:01.264840 - Starting section 14
# Step 0: rms = 0.501331
# 2025-01-23T19:00:01.264869 - Starting section 15
# iteration 1 out of 80
# in subtract mu
# 2025-01-23T19:00:01.265168 - Starting section 17
# update S
# 2025-01-23T19:00:01.268432 - Starting section 18
# 2025-01-23T19:00:01.268455 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.269185 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.269490 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.271154 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.288858 - Starting section 23
# 2025-01-23T19:00:01.288895 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.290368 - Starting section 25
# Step 1: cost = 1541.530317, rms = 0.394619
# 2025-01-23T19:00:01.290608 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.291019 - Starting section 27
# iteration 2 out of 80
# in subtract mu
# 2025-01-23T19:00:01.291473 - Starting section 17
# update S
# 2025-01-23T19:00:01.295082 - Starting section 18
# 2025-01-23T19:00:01.295109 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.296052 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.296508 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.298991 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.316616 - Starting section 23
# 2025-01-23T19:00:01.316651 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.318775 - Starting section 25
# Step 2: cost = 1451.004154, rms = 0.393590
# 2025-01-23T19:00:01.318987 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.319362 - Starting section 27
# iteration 3 out of 80
# in subtract mu
# 2025-01-23T19:00:01.320129 - Starting section 17
# update S
# 2025-01-23T19:00:01.323345 - Starting section 18
# 2025-01-23T19:00:01.323367 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.324236 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.324597 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.327050 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.344430 - Starting section 23
# 2025-01-23T19:00:01.344464 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.345771 - Starting section 25
# Step 3: cost = 1431.738313, rms = 0.384644
# 2025-01-23T19:00:01.345983 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.346278 - Starting section 27
# iteration 4 out of 80
# in subtract mu
# 2025-01-23T19:00:01.346993 - Starting section 17
# update S
# 2025-01-23T19:00:01.350150 - Starting section 18
# 2025-01-23T19:00:01.350171 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.351019 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.351693 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.353855 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.372696 - Starting section 23
# 2025-01-23T19:00:01.373140 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.374687 - Starting section 25
# Step 4: cost = 1333.707091, rms = 0.346410
# 2025-01-23T19:00:01.375189 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.375400 - Starting section 27
# iteration 5 out of 80
# in subtract mu
# 2025-01-23T19:00:01.375821 - Starting section 17
# update S
# 2025-01-23T19:00:01.379065 - Starting section 18
# 2025-01-23T19:00:01.379089 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.379824 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.380006 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.381662 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.398772 - Starting section 23
# 2025-01-23T19:00:01.398806 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.399853 - Starting section 25
# Step 5: cost = 1248.448540, rms = 0.319281
# 2025-01-23T19:00:01.400046 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.400191 - Starting section 27
# iteration 6 out of 80
# in subtract mu
# 2025-01-23T19:00:01.400419 - Starting section 17
# update S
# 2025-01-23T19:00:01.403480 - Starting section 18
# 2025-01-23T19:00:01.403502 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.404174 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.404346 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.406463 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.423793 - Starting section 23
# 2025-01-23T19:00:01.423824 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.424879 - Starting section 25
# Step 6: cost = 1230.227952, rms = 0.312730
# 2025-01-23T19:00:01.425069 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.425215 - Starting section 27
# iteration 7 out of 80
# in subtract mu
# 2025-01-23T19:00:01.425546 - Starting section 17
# update S
# 2025-01-23T19:00:01.428596 - Starting section 18
# 2025-01-23T19:00:01.428616 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.429275 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.429443 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.431256 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.448372 - Starting section 23
# 2025-01-23T19:00:01.448402 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.449451 - Starting section 25
# Step 7: cost = 1227.653663, rms = 0.311357
# 2025-01-23T19:00:01.449641 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.449784 - Starting section 27
# iteration 8 out of 80
# in subtract mu
# 2025-01-23T19:00:01.450094 - Starting section 17
# update S
# 2025-01-23T19:00:01.453169 - Starting section 18
# 2025-01-23T19:00:01.453190 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.453848 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.454017 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.455811 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.473153 - Starting section 23
# 2025-01-23T19:00:01.473206 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.474277 - Starting section 25
# Step 8: cost = 1227.070616, rms = 0.311012
# 2025-01-23T19:00:01.474466 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.474610 - Starting section 27
# iteration 9 out of 80
# in subtract mu
# 2025-01-23T19:00:01.474948 - Starting section 17
# update S
# 2025-01-23T19:00:01.477983 - Starting section 18
# 2025-01-23T19:00:01.478001 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.478657 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.478945 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.480632 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.497925 - Starting section 23
# 2025-01-23T19:00:01.497963 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.499022 - Starting section 25
# Step 9: cost = 1226.860088, rms = 0.310907
# 2025-01-23T19:00:01.499212 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.499486 - Starting section 27
# iteration 10 out of 80
# in subtract mu
# 2025-01-23T19:00:01.499667 - Starting section 17
# update S
# 2025-01-23T19:00:01.502709 - Starting section 18
# 2025-01-23T19:00:01.502730 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.503399 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.503562 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.505381 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.522664 - Starting section 23
# 2025-01-23T19:00:01.522762 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.523900 - Starting section 25
# Step 10: cost = 1226.762934, rms = 0.310867
# 2025-01-23T19:00:01.524093 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.524247 - Starting section 27
# iteration 11 out of 80
# in subtract mu
# 2025-01-23T19:00:01.524434 - Starting section 17
# update S
# 2025-01-23T19:00:01.527466 - Starting section 18
# 2025-01-23T19:00:01.527486 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.528141 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.528507 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.530199 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.547477 - Starting section 23
# 2025-01-23T19:00:01.547517 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.548582 - Starting section 25
# Step 11: cost = 1226.711415, rms = 0.310848
# 2025-01-23T19:00:01.548772 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.548919 - Starting section 27
# iteration 12 out of 80
# in subtract mu
# 2025-01-23T19:00:01.549101 - Starting section 17
# update S
# 2025-01-23T19:00:01.552130 - Starting section 18
# 2025-01-23T19:00:01.552149 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.552825 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.552996 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.554964 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.572139 - Starting section 23
# 2025-01-23T19:00:01.572263 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.573290 - Starting section 25
# Step 12: cost = 1226.681969, rms = 0.310838
# 2025-01-23T19:00:01.573477 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.573640 - Starting section 27
# iteration 13 out of 80
# in subtract mu
# 2025-01-23T19:00:01.573914 - Starting section 17
# update S
# 2025-01-23T19:00:01.576979 - Starting section 18
# 2025-01-23T19:00:01.577000 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.577671 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.577954 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.579557 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.596765 - Starting section 23
# 2025-01-23T19:00:01.596805 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.597894 - Starting section 25
# Step 13: cost = 1226.664514, rms = 0.310833
# 2025-01-23T19:00:01.598084 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.598233 - Starting section 27
# iteration 14 out of 80
# in subtract mu
# 2025-01-23T19:00:01.598419 - Starting section 17
# update S
# 2025-01-23T19:00:01.601488 - Starting section 18
# 2025-01-23T19:00:01.601507 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.602134 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.602637 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.604395 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.621719 - Starting section 23
# 2025-01-23T19:00:01.621765 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.622826 - Starting section 25
# Step 14: cost = 1226.654002, rms = 0.310830
# 2025-01-23T19:00:01.623018 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.623154 - Starting section 27
# iteration 15 out of 80
# in subtract mu
# 2025-01-23T19:00:01.623338 - Starting section 17
# update S
# 2025-01-23T19:00:01.626406 - Starting section 18
# 2025-01-23T19:00:01.626427 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.627088 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.627256 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.629203 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.646588 - Starting section 23
# 2025-01-23T19:00:01.646625 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.647660 - Starting section 25
# Step 15: cost = 1226.647640, rms = 0.310827
# 2025-01-23T19:00:01.647850 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.648116 - Starting section 27
# iteration 16 out of 80
# in subtract mu
# 2025-01-23T19:00:01.648293 - Starting section 17
# update S
# 2025-01-23T19:00:01.651371 - Starting section 18
# 2025-01-23T19:00:01.651391 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.652041 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.652217 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.653834 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.670906 - Starting section 23
# 2025-01-23T19:00:01.670962 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.672370 - Starting section 25
# Step 16: cost = 1226.643793, rms = 0.310826
# 2025-01-23T19:00:01.672563 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.672704 - Starting section 27
# iteration 17 out of 80
# in subtract mu
# 2025-01-23T19:00:01.672884 - Starting section 17
# update S
# 2025-01-23T19:00:01.675947 - Starting section 18
# 2025-01-23T19:00:01.675966 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.676623 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.676962 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.678567 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.695960 - Starting section 23
# 2025-01-23T19:00:01.696009 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.697049 - Starting section 25
# Step 17: cost = 1226.641479, rms = 0.310825
# 2025-01-23T19:00:01.697239 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.697381 - Starting section 27
# iteration 18 out of 80
# in subtract mu
# 2025-01-23T19:00:01.697585 - Starting section 17
# update S
# 2025-01-23T19:00:01.700625 - Starting section 18
# 2025-01-23T19:00:01.700644 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.701309 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.701469 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.703456 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.720869 - Starting section 23
# 2025-01-23T19:00:01.720923 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.721936 - Starting section 25
# Step 18: cost = 1226.640102, rms = 0.310825
# 2025-01-23T19:00:01.722134 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.722276 - Starting section 27
# iteration 19 out of 80
# in subtract mu
# 2025-01-23T19:00:01.722451 - Starting section 17
# update S
# 2025-01-23T19:00:01.725509 - Starting section 18
# 2025-01-23T19:00:01.725528 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.726189 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.726604 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.728312 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.745701 - Starting section 23
# 2025-01-23T19:00:01.745757 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.746796 - Starting section 25
# Step 19: cost = 1226.639294, rms = 0.310825
# 2025-01-23T19:00:01.746980 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.747127 - Starting section 27
# iteration 20 out of 80
# in subtract mu
# 2025-01-23T19:00:01.747445 - Starting section 17
# update S
# 2025-01-23T19:00:01.750520 - Starting section 18
# 2025-01-23T19:00:01.750539 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.751199 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.751490 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.753135 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.770435 - Starting section 23
# 2025-01-23T19:00:01.770485 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.771518 - Starting section 25
# Step 20: cost = 1226.638832, rms = 0.310824
# 2025-01-23T19:00:01.771706 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.771848 - Starting section 27
# iteration 21 out of 80
# in subtract mu
# 2025-01-23T19:00:01.772025 - Starting section 17
# update S
# 2025-01-23T19:00:01.775044 - Starting section 18
# 2025-01-23T19:00:01.775062 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.775709 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.776210 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.777833 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.795237 - Starting section 23
# 2025-01-23T19:00:01.795444 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.796483 - Starting section 25
# Step 21: cost = 1226.638577, rms = 0.310824
# 2025-01-23T19:00:01.796670 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.796806 - Starting section 27
# iteration 22 out of 80
# in subtract mu
# 2025-01-23T19:00:01.796991 - Starting section 17
# update S
# 2025-01-23T19:00:01.800023 - Starting section 18
# 2025-01-23T19:00:01.800043 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.800701 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.800854 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.802462 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.819954 - Starting section 23
# 2025-01-23T19:00:01.819994 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.821064 - Starting section 25
# Step 22: cost = 1226.638446, rms = 0.310824
# 2025-01-23T19:00:01.821255 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.821372 - Starting section 27
# iteration 23 out of 80
# in subtract mu
# 2025-01-23T19:00:01.821574 - Starting section 17
# update S
# 2025-01-23T19:00:01.824623 - Starting section 18
# 2025-01-23T19:00:01.824644 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.825334 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.825505 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.827125 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.844354 - Starting section 23
# 2025-01-23T19:00:01.844389 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.845470 - Starting section 25
# Step 23: cost = 1226.638385, rms = 0.310824
# 2025-01-23T19:00:01.845655 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.845801 - Starting section 27
# iteration 24 out of 80
# in subtract mu
# 2025-01-23T19:00:01.846021 - Starting section 17
# update S
# 2025-01-23T19:00:01.849061 - Starting section 18
# 2025-01-23T19:00:01.849081 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.849761 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.850733 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.852499 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.869962 - Starting section 23
# 2025-01-23T19:00:01.869998 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.871061 - Starting section 25
# Step 24: cost = 1226.638365, rms = 0.310824
# 2025-01-23T19:00:01.871253 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.871395 - Starting section 27
# iteration 25 out of 80
# in subtract mu
# 2025-01-23T19:00:01.871583 - Starting section 17
# update S
# 2025-01-23T19:00:01.874590 - Starting section 18
# 2025-01-23T19:00:01.874611 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.875276 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.875682 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.877310 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.894593 - Starting section 23
# 2025-01-23T19:00:01.894633 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.895714 - Starting section 25
# Step 25: cost = 1226.638367, rms = 0.310824
# 2025-01-23T19:00:01.895899 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.896042 - Starting section 27
# iteration 26 out of 80
# in subtract mu
# 2025-01-23T19:00:01.896257 - Starting section 17
# update S
# 2025-01-23T19:00:01.899272 - Starting section 18
# 2025-01-23T19:00:01.899291 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.899949 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.900110 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.902127 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.919360 - Starting section 23
# 2025-01-23T19:00:01.919543 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.920581 - Starting section 25
# Step 26: cost = 1226.638379, rms = 0.310824
# 2025-01-23T19:00:01.920766 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.920918 - Starting section 27
# iteration 27 out of 80
# in subtract mu
# 2025-01-23T19:00:01.921260 - Starting section 17
# update S
# 2025-01-23T19:00:01.924339 - Starting section 18
# 2025-01-23T19:00:01.924358 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.925022 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.925180 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.926800 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.944293 - Starting section 23
# 2025-01-23T19:00:01.944329 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.945356 - Starting section 25
# Step 27: cost = 1226.638396, rms = 0.310824
# 2025-01-23T19:00:01.945548 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.945697 - Starting section 27
# iteration 28 out of 80
# in subtract mu
# 2025-01-23T19:00:01.945887 - Starting section 17
# update S
# 2025-01-23T19:00:01.949282 - Starting section 18
# 2025-01-23T19:00:01.949414 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.950089 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.950357 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.952075 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.969541 - Starting section 23
# 2025-01-23T19:00:01.969579 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.970608 - Starting section 25
# Step 28: cost = 1226.638414, rms = 0.310824
# 2025-01-23T19:00:01.970794 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.970935 - Starting section 27
# iteration 29 out of 80
# in subtract mu
# 2025-01-23T19:00:01.971295 - Starting section 17
# update S
# 2025-01-23T19:00:01.974368 - Starting section 18
# 2025-01-23T19:00:01.974387 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:01.975045 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:01.975333 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:01.976966 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:01.994470 - Starting section 23
# 2025-01-23T19:00:01.994621 - Starting section 24
# in cf full
# 2025-01-23T19:00:01.995652 - Starting section 25
# Step 29: cost = 1226.638431, rms = 0.310824
# 2025-01-23T19:00:01.995839 - Starting section 26
# in converg check
# 2025-01-23T19:00:01.995983 - Starting section 27
# iteration 30 out of 80
# in subtract mu
# 2025-01-23T19:00:01.996301 - Starting section 17
# update S
# 2025-01-23T19:00:01.999377 - Starting section 18
# 2025-01-23T19:00:01.999399 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.000047 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.000205 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.001804 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.019152 - Starting section 23
# 2025-01-23T19:00:02.019316 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.020364 - Starting section 25
# Step 30: cost = 1226.638447, rms = 0.310824
# 2025-01-23T19:00:02.020555 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.020704 - Starting section 27
# iteration 31 out of 80
# in subtract mu
# 2025-01-23T19:00:02.021213 - Starting section 17
# update S
# 2025-01-23T19:00:02.024258 - Starting section 18
# 2025-01-23T19:00:02.024277 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.024947 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.025120 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.026732 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.044059 - Starting section 23
# 2025-01-23T19:00:02.044095 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.045105 - Starting section 25
# Step 31: cost = 1226.638460, rms = 0.310824
# 2025-01-23T19:00:02.045303 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.045467 - Starting section 27
# iteration 32 out of 80
# in subtract mu
# 2025-01-23T19:00:02.045664 - Starting section 17
# update S
# 2025-01-23T19:00:02.048720 - Starting section 18
# 2025-01-23T19:00:02.048744 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.049411 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.049561 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.051715 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.069091 - Starting section 23
# 2025-01-23T19:00:02.069153 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.070208 - Starting section 25
# Step 32: cost = 1226.638471, rms = 0.310824
# 2025-01-23T19:00:02.070406 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.070562 - Starting section 27
# iteration 33 out of 80
# in subtract mu
# 2025-01-23T19:00:02.070739 - Starting section 17
# update S
# 2025-01-23T19:00:02.073774 - Starting section 18
# 2025-01-23T19:00:02.073793 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.074454 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.074625 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.076592 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.093787 - Starting section 23
# 2025-01-23T19:00:02.093826 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.094915 - Starting section 25
# Step 33: cost = 1226.638481, rms = 0.310824
# 2025-01-23T19:00:02.095104 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.095259 - Starting section 27
# iteration 34 out of 80
# in subtract mu
# 2025-01-23T19:00:02.095442 - Starting section 17
# update S
# 2025-01-23T19:00:02.098471 - Starting section 18
# 2025-01-23T19:00:02.098490 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.099125 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.099309 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.101269 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.118762 - Starting section 23
# 2025-01-23T19:00:02.118803 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.119881 - Starting section 25
# Step 34: cost = 1226.638489, rms = 0.310824
# 2025-01-23T19:00:02.120071 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.120368 - Starting section 27
# iteration 35 out of 80
# in subtract mu
# 2025-01-23T19:00:02.121097 - Starting section 17
# update S
# 2025-01-23T19:00:02.124212 - Starting section 18
# 2025-01-23T19:00:02.124233 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.125085 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.125329 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.127225 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.145332 - Starting section 23
# 2025-01-23T19:00:02.145363 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.146505 - Starting section 25
# Step 35: cost = 1226.638495, rms = 0.310824
# 2025-01-23T19:00:02.146692 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.147014 - Starting section 27
# iteration 36 out of 80
# in subtract mu
# 2025-01-23T19:00:02.147669 - Starting section 17
# update S
# 2025-01-23T19:00:02.150800 - Starting section 18
# 2025-01-23T19:00:02.150819 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.151671 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.151979 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.154392 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.171738 - Starting section 23
# 2025-01-23T19:00:02.171771 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.173065 - Starting section 25
# Step 36: cost = 1226.638500, rms = 0.310824
# 2025-01-23T19:00:02.173260 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.173533 - Starting section 27
# iteration 37 out of 80
# in subtract mu
# 2025-01-23T19:00:02.174251 - Starting section 17
# update S
# 2025-01-23T19:00:02.177552 - Starting section 18
# 2025-01-23T19:00:02.177573 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.178332 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.178907 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.180988 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.198395 - Starting section 23
# 2025-01-23T19:00:02.198426 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.199637 - Starting section 25
# Step 37: cost = 1226.638504, rms = 0.310824
# 2025-01-23T19:00:02.199831 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.200073 - Starting section 27
# iteration 38 out of 80
# in subtract mu
# 2025-01-23T19:00:02.200418 - Starting section 17
# update S
# 2025-01-23T19:00:02.203581 - Starting section 18
# 2025-01-23T19:00:02.203602 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.204331 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.204645 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.206594 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.225104 - Starting section 23
# 2025-01-23T19:00:02.225140 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.226513 - Starting section 25
# Step 38: cost = 1226.638508, rms = 0.310824
# 2025-01-23T19:00:02.226703 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.226939 - Starting section 27
# iteration 39 out of 80
# in subtract mu
# 2025-01-23T19:00:02.227570 - Starting section 17
# update S
# 2025-01-23T19:00:02.230698 - Starting section 18
# 2025-01-23T19:00:02.230718 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.231516 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.231857 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.234223 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.251666 - Starting section 23
# 2025-01-23T19:00:02.251699 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.253007 - Starting section 25
# Step 39: cost = 1226.638511, rms = 0.310824
# 2025-01-23T19:00:02.253195 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.253554 - Starting section 27
# iteration 40 out of 80
# in subtract mu
# 2025-01-23T19:00:02.254275 - Starting section 17
# update S
# 2025-01-23T19:00:02.257409 - Starting section 18
# 2025-01-23T19:00:02.257429 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.258278 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.258593 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.260907 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.278397 - Starting section 23
# 2025-01-23T19:00:02.278426 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.279712 - Starting section 25
# Step 40: cost = 1226.638513, rms = 0.310824
# 2025-01-23T19:00:02.279909 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.280175 - Starting section 27
# iteration 41 out of 80
# in subtract mu
# 2025-01-23T19:00:02.280985 - Starting section 17
# update S
# 2025-01-23T19:00:02.284099 - Starting section 18
# 2025-01-23T19:00:02.284120 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.284935 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.285586 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.287700 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.305078 - Starting section 23
# 2025-01-23T19:00:02.305111 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.306387 - Starting section 25
# Step 41: cost = 1226.638515, rms = 0.310824
# 2025-01-23T19:00:02.306576 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.306914 - Starting section 27
# iteration 42 out of 80
# in subtract mu
# 2025-01-23T19:00:02.307619 - Starting section 17
# update S
# 2025-01-23T19:00:02.310768 - Starting section 18
# 2025-01-23T19:00:02.310788 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.311599 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.312220 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.314341 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.331686 - Starting section 23
# 2025-01-23T19:00:02.331718 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.332934 - Starting section 25
# Step 42: cost = 1226.638516, rms = 0.310824
# 2025-01-23T19:00:02.333125 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.333469 - Starting section 27
# iteration 43 out of 80
# in subtract mu
# 2025-01-23T19:00:02.334265 - Starting section 17
# update S
# 2025-01-23T19:00:02.337408 - Starting section 18
# 2025-01-23T19:00:02.337428 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.338230 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.338574 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.340636 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.358729 - Starting section 23
# 2025-01-23T19:00:02.358875 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.360047 - Starting section 25
# Step 43: cost = 1226.638517, rms = 0.310824
# 2025-01-23T19:00:02.360252 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.360524 - Starting section 27
# iteration 44 out of 80
# in subtract mu
# 2025-01-23T19:00:02.361215 - Starting section 17
# update S
# 2025-01-23T19:00:02.364530 - Starting section 18
# 2025-01-23T19:00:02.364552 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.365286 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.365861 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.367783 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.385352 - Starting section 23
# 2025-01-23T19:00:02.385394 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.386631 - Starting section 25
# Step 44: cost = 1226.638518, rms = 0.310824
# 2025-01-23T19:00:02.386822 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.387058 - Starting section 27
# iteration 45 out of 80
# in subtract mu
# 2025-01-23T19:00:02.388037 - Starting section 17
# update S
# 2025-01-23T19:00:02.391173 - Starting section 18
# 2025-01-23T19:00:02.391192 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.392013 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.392318 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.394702 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.412514 - Starting section 23
# 2025-01-23T19:00:02.412571 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.413823 - Starting section 25
# Step 45: cost = 1226.638519, rms = 0.310824
# 2025-01-23T19:00:02.414011 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.414261 - Starting section 27
# iteration 46 out of 80
# in subtract mu
# 2025-01-23T19:00:02.414877 - Starting section 17
# update S
# 2025-01-23T19:00:02.417993 - Starting section 18
# 2025-01-23T19:00:02.418014 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.418853 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.419182 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.421690 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.439142 - Starting section 23
# 2025-01-23T19:00:02.439173 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.440432 - Starting section 25
# Step 46: cost = 1226.638520, rms = 0.310824
# 2025-01-23T19:00:02.440627 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.440898 - Starting section 27
# iteration 47 out of 80
# in subtract mu
# 2025-01-23T19:00:02.441711 - Starting section 17
# update S
# 2025-01-23T19:00:02.444840 - Starting section 18
# 2025-01-23T19:00:02.444859 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.445683 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.445986 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.448390 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.466179 - Starting section 23
# 2025-01-23T19:00:02.466234 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.467492 - Starting section 25
# Step 47: cost = 1226.638520, rms = 0.310824
# 2025-01-23T19:00:02.467685 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.467980 - Starting section 27
# iteration 48 out of 80
# in subtract mu
# 2025-01-23T19:00:02.468682 - Starting section 17
# update S
# 2025-01-23T19:00:02.471817 - Starting section 18
# 2025-01-23T19:00:02.471837 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.472639 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.473293 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.475411 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.492800 - Starting section 23
# 2025-01-23T19:00:02.492830 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.494087 - Starting section 25
# Step 48: cost = 1226.638520, rms = 0.310824
# 2025-01-23T19:00:02.494287 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.494543 - Starting section 27
# iteration 49 out of 80
# in subtract mu
# 2025-01-23T19:00:02.494922 - Starting section 17
# update S
# 2025-01-23T19:00:02.498108 - Starting section 18
# 2025-01-23T19:00:02.498126 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.498876 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.499925 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.502034 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.519851 - Starting section 23
# 2025-01-23T19:00:02.519906 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.521127 - Starting section 25
# Step 49: cost = 1226.638520, rms = 0.310824
# 2025-01-23T19:00:02.521323 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.521554 - Starting section 27
# iteration 50 out of 80
# in subtract mu
# 2025-01-23T19:00:02.522387 - Starting section 17
# update S
# 2025-01-23T19:00:02.525531 - Starting section 18
# 2025-01-23T19:00:02.525550 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.526365 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.527004 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.529108 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.546595 - Starting section 23
# 2025-01-23T19:00:02.546627 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.547867 - Starting section 25
# Step 50: cost = 1226.638521, rms = 0.310824
# 2025-01-23T19:00:02.548072 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.548348 - Starting section 27
# iteration 51 out of 80
# in subtract mu
# 2025-01-23T19:00:02.549142 - Starting section 17
# update S
# 2025-01-23T19:00:02.552455 - Starting section 18
# 2025-01-23T19:00:02.552480 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.553262 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.553799 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.555917 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.573655 - Starting section 23
# 2025-01-23T19:00:02.573698 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.574879 - Starting section 25
# Step 51: cost = 1226.638521, rms = 0.310824
# 2025-01-23T19:00:02.575067 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.575372 - Starting section 27
# iteration 52 out of 80
# in subtract mu
# 2025-01-23T19:00:02.575701 - Starting section 17
# update S
# 2025-01-23T19:00:02.578887 - Starting section 18
# 2025-01-23T19:00:02.578907 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.579660 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.580011 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.581935 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.599725 - Starting section 23
# 2025-01-23T19:00:02.599778 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.601034 - Starting section 25
# Step 52: cost = 1226.638521, rms = 0.310824
# 2025-01-23T19:00:02.601222 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.601527 - Starting section 27
# iteration 53 out of 80
# in subtract mu
# 2025-01-23T19:00:02.602940 - Starting section 17
# update S
# 2025-01-23T19:00:02.606092 - Starting section 18
# 2025-01-23T19:00:02.606111 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.606919 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.607587 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.609720 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.627485 - Starting section 23
# 2025-01-23T19:00:02.627539 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.628784 - Starting section 25
# Step 53: cost = 1226.638521, rms = 0.310824
# 2025-01-23T19:00:02.628980 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.629277 - Starting section 27
# iteration 54 out of 80
# in subtract mu
# 2025-01-23T19:00:02.629645 - Starting section 17
# update S
# 2025-01-23T19:00:02.632831 - Starting section 18
# 2025-01-23T19:00:02.632851 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.633613 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.633955 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.636579 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.654009 - Starting section 23
# 2025-01-23T19:00:02.654039 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.655272 - Starting section 25
# Step 54: cost = 1226.638521, rms = 0.310824
# 2025-01-23T19:00:02.655460 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.655729 - Starting section 27
# iteration 55 out of 80
# in subtract mu
# 2025-01-23T19:00:02.656572 - Starting section 17
# update S
# 2025-01-23T19:00:02.659718 - Starting section 18
# 2025-01-23T19:00:02.659738 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.660548 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.661206 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.663376 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.681220 - Starting section 23
# 2025-01-23T19:00:02.681269 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.682507 - Starting section 25
# Step 55: cost = 1226.638521, rms = 0.310824
# 2025-01-23T19:00:02.682698 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.682927 - Starting section 27
# iteration 56 out of 80
# in subtract mu
# 2025-01-23T19:00:02.683689 - Starting section 17
# update S
# 2025-01-23T19:00:02.686836 - Starting section 18
# 2025-01-23T19:00:02.686857 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.687671 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.688323 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.690428 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.707858 - Starting section 23
# 2025-01-23T19:00:02.707888 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.709125 - Starting section 25
# Step 56: cost = 1226.638522, rms = 0.310824
# 2025-01-23T19:00:02.709319 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.709574 - Starting section 27
# iteration 57 out of 80
# in subtract mu
# 2025-01-23T19:00:02.709892 - Starting section 17
# update S
# 2025-01-23T19:00:02.713128 - Starting section 18
# 2025-01-23T19:00:02.713149 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.713909 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.714979 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.717107 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.734518 - Starting section 23
# 2025-01-23T19:00:02.734549 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.735778 - Starting section 25
# Step 57: cost = 1226.638521, rms = 0.310824
# 2025-01-23T19:00:02.735970 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.736216 - Starting section 27
# iteration 58 out of 80
# in subtract mu
# 2025-01-23T19:00:02.737031 - Starting section 17
# update S
# 2025-01-23T19:00:02.740165 - Starting section 18
# 2025-01-23T19:00:02.740185 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.741015 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.741353 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.743641 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.761449 - Starting section 23
# 2025-01-23T19:00:02.761506 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.762734 - Starting section 25
# Step 58: cost = 1226.638522, rms = 0.310824
# 2025-01-23T19:00:02.762928 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.763151 - Starting section 27
# iteration 59 out of 80
# in subtract mu
# 2025-01-23T19:00:02.764085 - Starting section 17
# update S
# 2025-01-23T19:00:02.767237 - Starting section 18
# 2025-01-23T19:00:02.767262 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.768058 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.768428 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.770663 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.788044 - Starting section 23
# 2025-01-23T19:00:02.788075 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.789343 - Starting section 25
# Step 59: cost = 1226.638521, rms = 0.310824
# 2025-01-23T19:00:02.789552 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.789824 - Starting section 27
# iteration 60 out of 80
# in subtract mu
# 2025-01-23T19:00:02.790870 - Starting section 17
# update S
# 2025-01-23T19:00:02.794165 - Starting section 18
# 2025-01-23T19:00:02.794201 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.794968 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.795309 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.797235 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.814944 - Starting section 23
# 2025-01-23T19:00:02.815043 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.816249 - Starting section 25
# Step 60: cost = 1226.638522, rms = 0.310824
# 2025-01-23T19:00:02.816440 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.816736 - Starting section 27
# iteration 61 out of 80
# in subtract mu
# 2025-01-23T19:00:02.817876 - Starting section 17
# update S
# 2025-01-23T19:00:02.821067 - Starting section 18
# 2025-01-23T19:00:02.821088 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.821872 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.822212 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.824542 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.842246 - Starting section 23
# 2025-01-23T19:00:02.842301 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.843520 - Starting section 25
# Step 61: cost = 1226.638522, rms = 0.310824
# 2025-01-23T19:00:02.843710 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.843951 - Starting section 27
# iteration 62 out of 80
# in subtract mu
# 2025-01-23T19:00:02.844854 - Starting section 17
# update S
# 2025-01-23T19:00:02.848003 - Starting section 18
# 2025-01-23T19:00:02.848023 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.848853 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.849165 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.851568 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.868990 - Starting section 23
# 2025-01-23T19:00:02.869021 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.870266 - Starting section 25
# Step 62: cost = 1226.638522, rms = 0.310824
# 2025-01-23T19:00:02.870461 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.870723 - Starting section 27
# iteration 63 out of 80
# in subtract mu
# 2025-01-23T19:00:02.871120 - Starting section 17
# update S
# 2025-01-23T19:00:02.874311 - Starting section 18
# 2025-01-23T19:00:02.874334 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:02.875094 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:02.875470 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:02.877403 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:02.896059 - Starting section 23
# 2025-01-23T19:00:02.896113 - Starting section 24
# in cf full
# 2025-01-23T19:00:02.897372 - Starting section 25
# Step 63: cost = 1226.638522, rms = 0.310824
# 2025-01-23T19:00:02.897563 - Starting section 26
# in converg check
# 2025-01-23T19:00:02.897801 - Starting section 27
# iteration 64 out of 80
# in subtract mu
# ...
# 2025-01-23T19:00:08.582605 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.582876 - Starting section 27
# iteration 39 out of 80
# in subtract mu
# 2025-01-23T19:00:08.583253 - Starting section 17
# update S
# 2025-01-23T19:00:08.586569 - Starting section 18
# 2025-01-23T19:00:08.586588 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.587404 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.588409 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.590633 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.608066 - Starting section 23
# 2025-01-23T19:00:08.608099 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.609344 - Starting section 25
# Step 39: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.609550 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.609872 - Starting section 27
# iteration 40 out of 80
# in subtract mu
# 2025-01-23T19:00:08.610653 - Starting section 17
# update S
# 2025-01-23T19:00:08.613893 - Starting section 18
# 2025-01-23T19:00:08.613915 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.614723 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.615390 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.617354 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.634732 - Starting section 23
# 2025-01-23T19:00:08.634788 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.636086 - Starting section 25
# Step 40: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.636304 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.636650 - Starting section 27
# iteration 41 out of 80
# in subtract mu
# 2025-01-23T19:00:08.637551 - Starting section 17
# update S
# 2025-01-23T19:00:08.640794 - Starting section 18
# 2025-01-23T19:00:08.640813 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.641666 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.641981 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.644465 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.662198 - Starting section 23
# 2025-01-23T19:00:08.662256 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.663487 - Starting section 25
# Step 41: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.663697 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.663960 - Starting section 27
# iteration 42 out of 80
# in subtract mu
# 2025-01-23T19:00:08.664708 - Starting section 17
# update S
# 2025-01-23T19:00:08.667941 - Starting section 18
# 2025-01-23T19:00:08.667964 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.668943 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.669222 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.671614 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.688951 - Starting section 23
# 2025-01-23T19:00:08.688983 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.690252 - Starting section 25
# Step 42: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.690460 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.690731 - Starting section 27
# iteration 43 out of 80
# in subtract mu
# 2025-01-23T19:00:08.691538 - Starting section 17
# update S
# 2025-01-23T19:00:08.694749 - Starting section 18
# 2025-01-23T19:00:08.694769 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.695607 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.695914 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.697916 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.715589 - Starting section 23
# 2025-01-23T19:00:08.715647 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.716871 - Starting section 25
# Step 43: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.717077 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.717307 - Starting section 27
# iteration 44 out of 80
# in subtract mu
# 2025-01-23T19:00:08.718607 - Starting section 17
# update S
# 2025-01-23T19:00:08.721840 - Starting section 18
# 2025-01-23T19:00:08.721859 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.722673 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.723351 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.725608 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.743057 - Starting section 23
# 2025-01-23T19:00:08.743090 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.744365 - Starting section 25
# Step 44: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.744585 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.744869 - Starting section 27
# iteration 45 out of 80
# in subtract mu
# 2025-01-23T19:00:08.745511 - Starting section 17
# update S
# 2025-01-23T19:00:08.748686 - Starting section 18
# 2025-01-23T19:00:08.748706 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.749540 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.749853 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.752532 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.770310 - Starting section 23
# 2025-01-23T19:00:08.770361 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.771612 - Starting section 25
# Step 45: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.771818 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.772077 - Starting section 27
# iteration 46 out of 80
# in subtract mu
# 2025-01-23T19:00:08.772452 - Starting section 17
# update S
# 2025-01-23T19:00:08.775718 - Starting section 18
# 2025-01-23T19:00:08.775737 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.776496 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.777424 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.779651 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.797138 - Starting section 23
# 2025-01-23T19:00:08.797171 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.798412 - Starting section 25
# Step 46: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.798616 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.798945 - Starting section 27
# iteration 47 out of 80
# in subtract mu
# 2025-01-23T19:00:08.799729 - Starting section 17
# update S
# 2025-01-23T19:00:08.802955 - Starting section 18
# 2025-01-23T19:00:08.802976 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.803835 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.804479 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.806444 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.824229 - Starting section 23
# 2025-01-23T19:00:08.824330 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.825592 - Starting section 25
# Step 47: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.825806 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.826035 - Starting section 27
# iteration 48 out of 80
# in subtract mu
# 2025-01-23T19:00:08.827098 - Starting section 17
# update S
# 2025-01-23T19:00:08.830329 - Starting section 18
# 2025-01-23T19:00:08.830352 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.831470 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.831699 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.833719 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.851549 - Starting section 23
# 2025-01-23T19:00:08.851601 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.852902 - Starting section 25
# Step 48: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.853120 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.853384 - Starting section 27
# iteration 49 out of 80
# in subtract mu
# 2025-01-23T19:00:08.853757 - Starting section 17
# update S
# 2025-01-23T19:00:08.857039 - Starting section 18
# 2025-01-23T19:00:08.857058 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.857870 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.858218 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.860216 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.878013 - Starting section 23
# 2025-01-23T19:00:08.878069 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.879312 - Starting section 25
# Step 49: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.879515 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.879751 - Starting section 27
# iteration 50 out of 80
# in subtract mu
# 2025-01-23T19:00:08.881693 - Starting section 17
# update S
# 2025-01-23T19:00:08.884953 - Starting section 18
# 2025-01-23T19:00:08.884975 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.885858 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.886176 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.888665 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.906272 - Starting section 23
# 2025-01-23T19:00:08.906302 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.907550 - Starting section 25
# Step 50: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.907765 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.908026 - Starting section 27
# iteration 51 out of 80
# in subtract mu
# 2025-01-23T19:00:08.908848 - Starting section 17
# update S
# 2025-01-23T19:00:08.912074 - Starting section 18
# 2025-01-23T19:00:08.912097 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.912964 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.913608 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.915557 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.933196 - Starting section 23
# 2025-01-23T19:00:08.933255 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.934444 - Starting section 25
# Step 51: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.934649 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.934983 - Starting section 27
# iteration 52 out of 80
# in subtract mu
# 2025-01-23T19:00:08.935908 - Starting section 17
# update S
# 2025-01-23T19:00:08.939135 - Starting section 18
# 2025-01-23T19:00:08.939154 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.939961 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.940293 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.942818 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.960682 - Starting section 23
# 2025-01-23T19:00:08.960746 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.961995 - Starting section 25
# Step 52: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.962202 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.962455 - Starting section 27
# iteration 53 out of 80
# in subtract mu
# 2025-01-23T19:00:08.962955 - Starting section 17
# update S
# 2025-01-23T19:00:08.966162 - Starting section 18
# 2025-01-23T19:00:08.966183 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.967029 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.967868 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:08.970093 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:08.989846 - Starting section 23
# 2025-01-23T19:00:08.989947 - Starting section 24
# in cf full
# 2025-01-23T19:00:08.991613 - Starting section 25
# Step 53: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:08.992270 - Starting section 26
# in converg check
# 2025-01-23T19:00:08.992569 - Starting section 27
# iteration 54 out of 80
# in subtract mu
# 2025-01-23T19:00:08.993325 - Starting section 17
# update S
# 2025-01-23T19:00:08.996639 - Starting section 18
# 2025-01-23T19:00:08.996662 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:08.997853 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:08.998159 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:09.000158 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:09.017866 - Starting section 23
# 2025-01-23T19:00:09.017920 - Starting section 24
# in cf full
# 2025-01-23T19:00:09.019142 - Starting section 25
# Step 54: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:09.019351 - Starting section 26
# in converg check
# 2025-01-23T19:00:09.019587 - Starting section 27
# iteration 55 out of 80
# in subtract mu
# 2025-01-23T19:00:09.020677 - Starting section 17
# update S
# 2025-01-23T19:00:09.023891 - Starting section 18
# 2025-01-23T19:00:09.023910 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:09.024807 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:09.025087 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:09.027512 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:09.045035 - Starting section 23
# 2025-01-23T19:00:09.045068 - Starting section 24
# in cf full
# 2025-01-23T19:00:09.046354 - Starting section 25
# Step 55: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:09.046562 - Starting section 26
# in converg check
# 2025-01-23T19:00:09.046906 - Starting section 27
# iteration 56 out of 80
# in subtract mu
# 2025-01-23T19:00:09.047703 - Starting section 17
# update S
# 2025-01-23T19:00:09.050920 - Starting section 18
# 2025-01-23T19:00:09.050941 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:09.051812 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:09.052169 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:09.054700 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:09.072462 - Starting section 23
# 2025-01-23T19:00:09.072512 - Starting section 24
# in cf full
# 2025-01-23T19:00:09.073753 - Starting section 25
# Step 56: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:09.073965 - Starting section 26
# in converg check
# 2025-01-23T19:00:09.074219 - Starting section 27
# iteration 57 out of 80
# in subtract mu
# 2025-01-23T19:00:09.074948 - Starting section 17
# update S
# 2025-01-23T19:00:09.078166 - Starting section 18
# 2025-01-23T19:00:09.078189 - Starting section 19
# in rotate to pca
# 2025-01-23T19:00:09.079016 - Starting section 20
# in subtract mu
# 2025-01-23T19:00:09.079384 - Starting section 21
# Update A
# in compute rms
# 2025-01-23T19:00:09.081430 - Starting section 22
# Update V
# iterations number: 2341
# 2025-01-23T19:00:09.098822 - Starting section 23
# 2025-01-23T19:00:09.098853 - Starting section 24
# in cf full
# 2025-01-23T19:00:09.100144 - Starting section 25
# Step 57: cost = 1192.001887, rms = 0.246340
# 2025-01-23T19:00:09.100355 - Starting section 26
# in converg check
# 2025-01-23T19:00:09.100691 - Starting section 27
# iteration 58 out of 80
# in subtract mu
# 2025-01-23T19:00:09.101882 - Starting section 17
# update S
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 160
#     149 for k in range(1):  # Change if you want to do replications
#     151     opts = {
#     152         'maxiters': 80,
#     153         'algorithm': 'vb',
#    (...)
#     157         'minangle': 0
#     158     }
# --> 160     result = pca_full(np.copy(X_), z, **opts)
#     161     A = result['A']
#     162     S = result['S']
#
# File ~/projects_shany/VBPCA_py/src/vbpca_py/pca_full.py:234, in pca_full(X, ncomp, **kwargs)
#     232         S[:, j] = invPsi @ A_j.T @ X[:, j]
#     233         Sv[j] = V * invPsi
# --> 234         print_progress(opts['verbose'], j + 1, n2, 'Updating S:')
#     235 else:
#     236     for k in range(nobscomb):
#
# File ~/projects_shany/VBPCA_py/src/vbpca_py/pca_full.py:683, in print_progress(verbose, i, n, string)
#     674         print(f"print_progress_bar: {string}", flush=True)
#     675         # print("\n|                                                  |\r|")
#     676
#     677 ##############################################################################################
#    (...)
#     680 #Gets a verbosity level (`verbose`), current iteration index (`i`), total iterations (`n`), and a descriptive message (`string`).
#     681 #Returns nothing; outputs the progress message to the console if `verbose` equals 2.
# --> 683 def print_progress(verbose, i, n, string):
#     684     if verbose == 2:
#     685         print("print_progress", flush=True)
#
# KeyboardInterrupt:
