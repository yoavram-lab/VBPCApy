# %%
import sys
import os
sys.path.append(os.path.abspath("../../src/vbpca_py"))
from argschk import argschk

opts_default = {'init': 'random', 'maxiters': 1000}
opts, wrnmsg = argschk(opts_default, maxiters=500, Algorithm='vb')
print(opts)
print(wrnmsg)
# Out:
# in argschk
# {'init': 'random', 'maxiters': 500, 'algorithm': 'vb'}
# Unknown parameter(s): algorithm
