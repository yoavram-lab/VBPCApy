# %%
import sys
import os
sys.path.append(os.path.abspath("../../src/vbpca_py"))
from miscomb import miscomb

# %%
# Test Case 1

import numpy as np

M = np.array([
    [1, np.nan, 1, np.nan],
    [2, np.nan, 2, np.nan],
    [3, np.nan, 3, np.nan]
])

verbose = True

nobscomb_p, obscombj_p, Isv_p = miscomb(M, verbose)

# Display results
print('Python Results:')
print(f'nobscomb_p: {nobscomb_p}')
print('obscombj_p:')
print(obscombj_p)
print('Isv_p:')
print(Isv_p)
# Out:
# in miscomb
# calculating Isv..
# done
# Missing values combinations: found 3 in 4 columns
# Python Results:
# nobscomb_p: 3
# obscombj_p:
# [[0, 2], [1], [3]]
# Isv_p:
# [0 1 0 2]

# %%
# Test Case 2

import numpy as np

M = np.array([
    [1, np.nan, np.nan, 1],
    [np.nan, 2, np.nan, 2],
    [np.nan, np.nan, 3, np.nan]
])

verbose = True

nobscomb_p, obscombj_p, Isv_p = miscomb(M, verbose)

# Display results
print('Python Results:')
print(f'nobscomb_p: {nobscomb_p}')
print('obscombj_p:')
print(obscombj_p)
print('Isv_p:')
print(Isv_p)
# Out:
# in miscomb
# calculating Isv..
# done
# Missing values combinations: found 4 in 4 columns
# Python Results:
# nobscomb_p: 4
# obscombj_p:
# []
# Isv_p:
# []

# %%
# Test Case 3

import numpy as np

M = np.array([
    [1, np.nan, 1, 2, np.nan, 2],
    [np.nan, 2, np.nan, 3, 3, np.nan],
    [3, np.nan, 3, np.nan, np.nan, np.nan]
])

verbose = True

nobscomb_p, obscombj_p, Isv_p = miscomb(M, verbose)

# Display results
print('Python Results:')
print(f'nobscomb_p: {nobscomb_p}')
print('obscombj_p:')
print(obscombj_p)
print('Isv_p:')
print(Isv_p)
# Out:
# in miscomb
# calculating Isv..
# done
# Missing values combinations: found 6 in 6 columns
# Python Results:
# nobscomb_p: 6
# obscombj_p:
# []
# Isv_p:
# []
