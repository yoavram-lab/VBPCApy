# %%
# compute_rms_test.py

# Test 1: Dense Matrices
print('Test 1: Dense Matrices')

import numpy as np
import scipy.io
from compute_rms import compute_rms  # Your compute_rms function

# Load data from 'test_data.mat' generated by MATLAB!!!!
data = scipy.io.loadmat('test_data_compute_rms/test_data.mat')
X = data['X']
A = data['A']
S = data['S']
M = data['M']
ndata = data['ndata'].item()
rms_matlab = data['rms_matlab'].item()

# Ensure data types are appropriate
X = np.array(X, dtype=np.float64)
A = np.array(A, dtype=np.float64)
S = np.array(S, dtype=np.float64)
M = np.array(M, dtype=np.float64)

# Compute RMS using Python function
rms_python, errMx_python = compute_rms(X, A, S, M, ndata)

print(f'RMS (Python): {rms_python}')
print(f'RMS (MATLAB): {rms_matlab}')

# Compare RMS values
tolerance = 1e-10
if abs(rms_python - rms_matlab) < tolerance:
    print('Test passed: RMS values match.')
else:
    print('Test failed: RMS values do not match.')
# Out:
# Test 1: Dense Matrices
# befor is sparse
# RMS (Python): 0.5894039159358536
# RMS (MATLAB): 0.5894039159358536
# Test passed: RMS values match.

# %%
# compute_rms_test_case2.py

# Test 2: Sparse X
print('Test 2: Sparse X')

import numpy as np
import scipy.io
import scipy.sparse as sp
from compute_rms import compute_rms  # Ensure compute_rms and errpca_pt are properly implemented

# Load data from 'test_data_case2.mat' generated by MATLAB
data = scipy.io.loadmat('test_data_compute_rms/test_data_case2.mat')

# Reconstruct the sparse matrix X
X_sparse = data['X_sparse']
iX = X_sparse['i'][0, 0].flatten() - 1  # Adjust for MATLAB's 1-based indexing
jX = X_sparse['j'][0, 0].flatten() - 1
vX = X_sparse['v'][0, 0].flatten()
X_shape = X_sparse['size'][0, 0].flatten().astype(int)
X = sp.csr_matrix((vX, (iX, jX)), shape=(X_shape[0], X_shape[1]))

# Load other matrices
A = data['A']
S = data['S']
M = data['M']
ndata = int(data['ndata'][0, 0])
rms_matlab = data['rms_matlab'][0, 0]

# Ensure data types are appropriate
A = np.array(A, dtype=np.float64)
S = np.array(S, dtype=np.float64)
M = np.array(M, dtype=np.float64)

# Compute RMS using Python function
rms_python, errMx_python = compute_rms(X, A, S, M, ndata)

print(f'RMS (Python): {rms_python}')
print(f'RMS (MATLAB): {rms_matlab}')

# Compare RMS values
tolerance = 1e-10
if abs(rms_python - rms_matlab) < tolerance:
    print('Test passed: RMS values match.')
else:
    print('Test failed: RMS values do not match.')
# Out:
# Test 2: Sparse X
# Arguments sent to errpca_pt:
# X_data: [0.74313247 0.39222702 0.65547789 0.17118669 0.70604609 0.03183285
#  0.27692298 0.04617139 0.09713178 0.82345783]
# X_indices: [0 3 4 4 3 4 0 2 3 4]
# X_indptr: [ 0  3  4  5  6 10]
# A: [[0.69482862 0.38155846 0.4455862 ]
#  [0.31709948 0.76551679 0.64631301]
#  [0.95022205 0.7951999  0.70936483]
#  [0.03444608 0.1868726  0.75468668]
#  [0.43874436 0.4897644  0.27602508]]
# S: [[0.67970268 0.11899768 0.34038573 0.75126706 0.69907672]
#  [0.655098   0.49836405 0.58526775 0.25509512 0.89090325]
#  [0.16261174 0.95974396 0.22381194 0.50595705 0.95929143]]
# numCPU: 1
# Returned from errpca_pt:
# errMx data: [-0.05156014 -0.45255602 -0.59763932 -1.3524941  -0.56958419 -0.88269748
#  -0.38702133 -0.45159194 -0.49707574 -0.18437932]
# errMx indices: [0 3 4 4 3 4 0 2 3 4]
# errMx indptr: [ 0  3  4  5  6 10]
# errMx shape: (5, 5)
# RMS (Python): 0.6428265901925508
# RMS (MATLAB): 0.6428265901925508
# Test passed: RMS values match.

# %%
# compute_rms_test_case3.py

# Test 3: Empty X
print('Test 3: Empty X')

import numpy as np
import scipy.io
from compute_rms import compute_rms

# Load data from 'test_data_compute_rms/test_data_case3.mat' generated by MATLAB
data = scipy.io.loadmat('test_data_compute_rms/test_data_case3.mat')
X = data['X']  # Should be an empty array
A = data['A']
S = data['S']
M = data['M']
ndata = int(data['ndata'][0, 0])
rms_matlab = data['rms_matlab'][0, 0]

# Convert data to appropriate types
X = np.array(X)
A = np.array(A, dtype=np.float64)
S = np.array(S, dtype=np.float64)
M = np.array(M)

# Compute RMS using Python function
rms_python, errMx_python = compute_rms(X, A, S, M, ndata)

print(f'RMS (Python): {rms_python}')
print(f'RMS (MATLAB): {rms_matlab}')

# Compare RMS values
if (np.isnan(rms_python) and np.isnan(rms_matlab)) or abs(rms_python - rms_matlab) < 1e-10:
    print('Test passed: RMS values match.')
else:
    print('Test failed: RMS values do not match.')
# Out:
# Test 3: Empty X
# RMS (Python): nan
# RMS (MATLAB): nan
# Test passed: RMS values match.

# %%
# compute_rms_test_case4.py

# Test 4: Different Sizes
print('Test 4: Different Sizes')

import numpy as np
import scipy.io
from compute_rms import compute_rms

# Load data from 'test_data_compute_rms/test_data_case4.mat' generated by MATLAB
data = scipy.io.loadmat('test_data_compute_rms/test_data_case4.mat')
X = data['X']
A = data['A']
S = data['S']
M = data['M']
ndata = int(data['ndata'][0, 0])
rms_matlab = data['rms_matlab'][0, 0]

# Ensure data types are appropriate
X = np.array(X, dtype=np.float64)
A = np.array(A, dtype=np.float64)
S = np.array(S, dtype=np.float64)
M = np.array(M, dtype=np.float64)

# Compute RMS using Python function
rms_python, errMx_python = compute_rms(X, A, S, M, ndata)

print(f'RMS (Python): {rms_python}')
print(f'RMS (MATLAB): {rms_matlab}')

# Compare RMS values
tolerance = 1e-10
if abs(rms_python - rms_matlab) < tolerance:
    print('Test passed: RMS values match.')
else:
    print('Test failed: RMS values do not match.')
# Out:
# Test 4: Different Sizes
# RMS (Python): 0.7546709968605863
# RMS (MATLAB): 0.7546709968605863
# Test passed: RMS values match.

# %%
# compute_rms_test_case5.py

# Test 5: Sparse M
print('Test 5: Sparse M')

import numpy as np
import scipy.io
import scipy.sparse as sp
from compute_rms import compute_rms

# Load data from 'test_data_compute_rms/test_data_case5.mat' generated by MATLAB
data = scipy.io.loadmat('test_data_compute_rms/test_data_case5.mat')

# Reconstruct the sparse matrix M
M_sparse = data['M_sparse']
iM = M_sparse['i'][0, 0].flatten() - 1
jM = M_sparse['j'][0, 0].flatten() - 1
vM = M_sparse['v'][0, 0].flatten()
M_shape = M_sparse['size'][0, 0].flatten().astype(int)
M = sp.csr_matrix((vM, (iM, jM)), shape=(M_shape[0], M_shape[1]))

# Load other matrices
X = data['X']
A = data['A']
S = data['S']
ndata = int(data['ndata'][0, 0])
rms_matlab = data['rms_matlab'][0, 0]

# Ensure data types are appropriate
X = np.array(X, dtype=np.float64)
A = np.array(A, dtype=np.float64)
S = np.array(S, dtype=np.float64)

# Compute RMS using Python function
rms_python, errMx_python = compute_rms(X, A, S, M, ndata)

print(f'RMS (Python): {rms_python}')
print(f'RMS (MATLAB): {rms_matlab}')

# Compare RMS values
tolerance = 1e-10
if abs(rms_python - rms_matlab) < tolerance:
    print('Test passed: RMS values match.')
else:
    print('Test failed: RMS values do not match.')
# Out:
# Test 5: Sparse M
# RMS (Python): 0.36544899224981364
# RMS (MATLAB): 0.36544899224981364
# Test passed: RMS values match.

# %%
# compute_rms_test_case6.py

# Test 6: Negative Values
print('Test 6: Negative Values')

import numpy as np
import scipy.io
from compute_rms import compute_rms

# Load data from 'test_data_compute_rms/test_data_case6.mat' generated by MATLAB
data = scipy.io.loadmat('test_data_compute_rms/test_data_case6.mat')
X = data['X']
A = data['A']
S = data['S']
M = data['M']
ndata = int(data['ndata'][0, 0])
rms_matlab = data['rms_matlab'][0, 0]

# Ensure data types are appropriate
X = np.array(X, dtype=np.float64)
A = np.array(A, dtype=np.float64)
S = np.array(S, dtype=np.float64)
M = np.array(M, dtype=np.float64)

# Compute RMS using Python function
rms_python, errMx_python = compute_rms(X, A, S, M, ndata)

print(f'RMS (Python): {rms_python}')
print(f'RMS (MATLAB): {rms_matlab}')

# Compare RMS values
tolerance = 1e-10
if abs(rms_python - rms_matlab) < tolerance:
    print('Test passed: RMS values match.')
else:
    print('Test failed: RMS values do not match.')
# Out:
# Test 6: Negative Values
# RMS (Python): 0.36592562150515573
# RMS (MATLAB): 0.36592562150515573
# Test passed: RMS values match.

# %%
# compute_rms_test_case7.py

# Test 7: Non-Square Matrices
print('Test 7: Non-Square Matrices')

import numpy as np
import scipy.io
from compute_rms import compute_rms

# Load data from 'test_data_compute_rms/test_data_case7.mat' generated by MATLAB
data = scipy.io.loadmat('test_data_compute_rms/test_data_case7.mat')
X = data['X']
A = data['A']
S = data['S']
M = data['M']
ndata = int(data['ndata'][0, 0])
rms_matlab = data['rms_matlab'][0, 0]

# Ensure data types are appropriate
X = np.array(X, dtype=np.float64)
A = np.array(A, dtype=np.float64)
S = np.array(S, dtype=np.float64)
M = np.array(M, dtype=np.float64)

# Compute RMS using Python function
rms_python, errMx_python = compute_rms(X, A, S, M, ndata)

print(f'RMS (Python): {rms_python}')
print(f'RMS (MATLAB): {rms_matlab}')

# Compare RMS values
tolerance = 1e-10
if abs(rms_python - rms_matlab) < tolerance:
    print('Test passed: RMS values match.')
else:
    print('Test failed: RMS values do not match.')
# Out:
# Test 7: Non-Square Matrices
# RMS (Python): 0.7676887908488137
# RMS (MATLAB): 0.7676887908488137
# Test passed: RMS values match.

# %%
# compute_rms_test_case8.py

# Test 8: Large Matrices
print('Test 8: Large Matrices')

import numpy as np
import scipy.io
from compute_rms import compute_rms

# Load data from 'test_data_compute_rms/test_data_case8.mat' generated by MATLAB
data = scipy.io.loadmat('test_data_compute_rms/test_data_case8.mat')
X = data['X']
A = data['A']
S = data['S']
M = data['M']
ndata = int(data['ndata'][0, 0])
rms_matlab = data['rms_matlab'][0, 0]

# Ensure data types are appropriate
X = np.array(X, dtype=np.float64)
A = np.array(A, dtype=np.float64)
S = np.array(S, dtype=np.float64)
M = np.array(M, dtype=np.float64)

# Compute RMS using Python function
rms_python, _ = compute_rms(X, A, S, M, ndata)

print(f'RMS (Python): {rms_python}')
print(f'RMS (MATLAB): {rms_matlab}')

# Compare RMS values
tolerance = 1e-8  # Use a slightly larger tolerance due to potential numerical differences
if abs(rms_python - rms_matlab) < tolerance:
    print('Test passed: RMS values match.')
else:
    print('Test failed: RMS values do not match.')
# Out:
# Test 8: Large Matrices
# RMS (Python): 11.962848820421566
# RMS (MATLAB): 11.962848820421566
# Test passed: RMS values match.

# %%
from scipy.io import loadmat
import numpy as np
from scipy.sparse import csr_matrix  # Import csr_matrix for sparse matrices
from compute_rms import compute_rms  # Ensure this module is available

# Load MATLAB data
data = loadmat('test3_data.mat')

# Extract variables
# Convert X_sparse to a sparse matrix in Python
X = csr_matrix(data['X_sparse'])  # Ensures X is sparse
A = data['A']
S = data['S']
Mu = data['Mu']
V = data['V'][0][0]
Av = data['Av']
Sv = data['Sv']
Isv = data['Isv']
Muv = data['Muv']
Va = data['Va']
Vmu = data['Vmu'][0][0]
M = data['M']
sXv = data['sXv']
ndata = data['ndata']

# Call compute_rms or other functions as needed
# For example, if compute_rms is the function being tested
rms_py, errMx_py = compute_rms(X, A, S, M, ndata)

# Print results
print("RMS Error (Python):", rms_py)
print("Reconstruction Error Matrix (Python):\n", errMx_py)
# Out:
# Arguments sent to errpca_pt:
# X_data: [1. 4.]
# X_indices: [0 1]
# X_indptr: [0 1 2]
# A: [[-0.5382  0.976 ]
#  [ 0.8672  0.3374]]
# S: [[-0.9961 -1.2974]
#  [-0.5232  0.9174]]
# numCPU: 1
# Returned from errpca_pt:
# errMx data: [0.97454218 4.81557452]
# errMx indices: [0 1]
# errMx indptr: [0 1 2]
# errMx shape: (2, 2)
# RMS Error (Python): 2.4565977702033552
# Reconstruction Error Matrix (Python):
#    (0, 0)	0.9745421799999999
#   (1, 1)	4.81557452
#
# RMS Error (MATLAB): 2.4565977702033552
# Reconstruction Error Matrix (MATLAB):
#    (0, 0)	0.9745421799999999
#   (1, 1)	4.81557452
