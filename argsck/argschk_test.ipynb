# %%
from argschk import argschk

opts_default = {'init': 'random', 'maxiters': 1000}
opts, wrnmsg = argschk(opts_default, maxiters=500, Algorithm='vb')
print(opts)
print(wrnmsg)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from argschk import argschk
#       3 opts_default = {'init': 'random', 'maxiters': 1000}
#       4 opts, wrnmsg = argschk(opts_default, maxiters=500, Algorithm='vb')
#
# ModuleNotFoundError: No module named 'argschk'
